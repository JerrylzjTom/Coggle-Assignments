# %%
import jieba
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pprint
import warnings
warnings.simplefilter('ignore')

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_predict

# %%
data_dir = 'https://mirror.coggle.club/dataset/coggle-competition/'
train_data = pd.read_csv(data_dir + 'intent-classify/train.csv', sep='\t', header=None)
test_data = pd.read_csv(data_dir + 'intent-classify/test.csv', sep='\t', header=None)
cn_stopwords = pd.read_csv('https://mirror.coggle.club/stopwords/baidu_stopwords.txt', header=None)[0].values

# %%
# 读取中文停用词
cn_stopwords = ' '.join(pd.read_csv('https://mirror.coggle.club/stopwords/baidu_stopwords.txt', header=None)[0])

# %%
corpus = train_data[0]

# %%
texts = []

for i in range(len(corpus)):
    content = ''.join(corpus.iloc[i])
    words = jieba.lcut(content)
    texts.append(words)    

# Count word frequencies
from collections import defaultdict
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

processed_corpus = [[token for token in text if frequency[token] > 1] for text in texts]
pprint.pprint(processed_corpus)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache D:\Temp\jieba.cache
# Loading model cost 0.629 seconds.
# Prefix dict has been built successfully.
# [['还有', '双鸭山', '到', '的', '汽车票', '吗', '13', '号', '的'],
#  ['从', '这里', '怎么', '回家'],
#  ['随便', '播放', '一首', '专辑', '里', '的', '的', '歌'],
#  ['给', '看', '一下', '嘛'],
#  ['我', '想', '看', '挑战', '打', '团', '竞', '的', '游戏', '视频'],
#  ['我', '想', '看', '和平', '精英', '上', '的', '游戏', '视频'],
#  ['2019', '年', '古装', '爱情', '电视剧', '小女', '花不弃', '的', '花絮', '播放', '一下'],
#  ['找', '一个', '年', '的', '推理', '剧给', '我', '看', '一会', '呢'],
#  ['去', '深圳', '都', '经过', '那些', '地方', '啊'],
#  ['给', '我', '转播', '今天', '的', '女子双打', '乒乓球', '比赛', '现场'],
#  ['单曲', '循环', '一首', '催眠', '的', '歌', '吧'],
#  ['你', '能', '播放', '一下', '曹盾', '导演', '的', '古装', '悬疑剧', '呢'],
#  ['河南', '新闻广播', '找', '一下', '啊', '是', '新闻台'],
#  ['交通', '类', '的', '武汉', '交通', '广播电台', '来', '一个', '吧'],
#  ['播放', '香港电台', '的', '王菲', '的', '经典音乐'],
#  ['给', '我', '找', '一个', '魔兽', '世界', '的', '比赛', '视频'],
#  ['播放', '钢琴曲', '命运', '交响曲'],
#  ['早上', '七点', '开', '空调'],
#  ['查询', '北京', '飞', '桂林', '的', '飞机', '是否', '已经', '起飞', '了'],
#  ['播放', '中央', '电台', '里', '的', '都市', '之声'],
#  ['客厅', '空调', '风速', '低', '一些', '低', '一些'],
#  ['海南', '今天', '几级', '风'],
#  ['打开', '烤箱', '的', '开关'],
#  ['帮', '我定', '一个', '22', '号', '下午', '2', '点', '参加', '公司', '的', '闹钟', '。'],
#  ['儿童房', '的', '空调', '调高', '4', '度'],
#  ['6', '月', '18', '号', '零点', '的', '拍卖', '活动', '提醒', '我', '一下', '。'],
#  ['能', '随机', '给', '我', '来', '一个', '赵丽颖', '2020', '年', '上', '的', '剧', '吗'],
#  ['麻烦',
#   '帮',
#   '我',
#   '创建',
#   '一个',
#   '周末',
#   '上午',
#   '8',
#   '点',
#   '和',
#   '女朋友',
#   '的',
#   '约会',
#   '提醒',
#   '。'],
#  ['我要', '听', '治愈', '系', '的', '日语', '歌曲'],
#  ['我', '一定', '要', '单曲', '循环', '赵雷', '的', '我们', '的', '时光', '这首', '流行'],
#  ['5', '月', '8', '号', '下午', '4', '点', '之前', '的', '提醒', '取消', '掉'],
#  ['让', '洗衣机', '停止', '工作', '好', '吗'],
#  ['昨天', '秦岭', '是不是', '刮风', '了'],
#  ['我要', '出去', '旅游', '几天', '，', '帮', '我', '把', '灯', '设置', '为', '模式', '吧'],
#  ['音乐', '老友记', '我', '是', '山西', '音乐', '广播', '的'],
#  ['我', '想', '看', '2020', '年谍', '战', '电视剧', '秋蝉', '第三集', '花絮'],
#  ['能', '把', '家庭', '剧小', '给', '我', '播放', '一下', '吗'],
#  ['五一劳动节', '是', '农历', '几时'],
#  ['杨延东', '2021', '年', '上线', '的', '剧', '播放', '来', '看看', '呢'],
#  ['播放', '美国', '推理', '电影', '蜘蛛侠'],
#  ['快点',
#   '帮',
#   '我定',
#   '一个',
#   '周末',
#   '上午',
#   '9',
#   '点',
#   '跟',
#   '家人',
#   '一起',
#   '去',
#   '动物园',
#   '的',
#   '闹钟',
#   '。'],
#  ['把', '主持', '的', '神州', '之声', '播放', '一下', '呢'],
#  ['快帮', '我查', '一下', '明天', '是', '星期', '几'],
#  ['可不可以', '把', '电饭煲', '开', '到', '蛋糕', '模式', '呢'],
#  ['查询', '衡水', '晚上', '气温', '多少'],
#  ['订', '三张', '明天', '早上', '飞', '成都', '的', '经济舱'],
#  ['农历', '的', '3', '月', '26', '是', '几号'],
#  ['下', '周六', '我', '爷爷', '让', '我', '去', '买', '，', '记得', '提醒', '我'],
#  ['明天', '叫', '我', '去', '森林', '野炊'],
#  ['龙抬头', '是', '什么', '时候'],
#  ['明天', '9', '点', '的', '闹钟', '不要', '再响', '了'],
#  ['给',
#   '我',
#   '播放',
#   '解说',
#   '今年',
#   '讲解',
#   '的',
#   '所有',
#   '关于',
#   '植物',
#   '大战',
#   '僵尸',
#   '的',
#   '视频'],
#  ['播放', '一首', '适合', '开心', '时候', '听', '的', '歌曲', '呢'],
#  ['快', '告诉', '我', '周四', '下午', '到', '杭州', '的', '航班'],
#  ['这个', '水壶', '可以', '关闭', '了'],
#  ['我', '想', '听', '的', '播放', '一下', '不'],
#  ['很', '想', '看', '日本', '的', '电影', '预告', '随便', '播', '一个', '给', '我'],
#  ['给', '我', '来', '一个', '美国', '的', '漫威', '系列', '电影', '侠', '1', '吧'],
#  ['查找', '国产', '动漫', '全职', '高手', '第一季'],
#  ['有个', '美国', '电影', '口碑', '不错', '，', '我要', '看看'],
#  ['找', '主播', '的', '在', '成都'],
#  ['香港', '的', '电视剧', '鹿鼎记', '第三集', '花絮', '播放', '出来'],
#  ['帮', '我查', '一下', '紫外线', '指数', '是', '多少', '。'],
#  ['马上', '查询', '一下', '明天', '有飞', '广州', '的', '飞机', '吗'],
#  ['2011', '年', '最', '浪漫', '的', '歌来', '一首', '呗'],
#  ['经济',
#   '类',
#   '的',
#   '广州',
#   '人民',
#   '广播电台',
#   '经济',
#   '环保',
#   '广播',
#   '可以',
#   '收听',
#   '给',
#   '我',
#   '吗'],
#  ['把', '卧室', '的', '空调', '开', '到', '十八', '度'],
#  ['来放', '一个', '德语', '歌曲', '给', '我', '吧'],
#  ['今日', '法国', '有', '什么', '新闻', '看', '呢'],
#  ['我', '想', '听', '开浩御', '书房', '的'],
#  ['播', '一个', '晚上', '23', '点', '45', '更新', '的', '国产', '动漫'],
#  ['斗罗', '大陆', '放', '第', '13', '集'],
#  ['古尔邦节', '是', '农历', '的', '什么', '时候'],
#  ['王力宏', '2019', '年', '演唱会', '的', '视频', '找', '来', '看看'],
#  ['温度', '咋', '还是', '这么', '低', '，', '告诉', '我下', '取暖器', '现在', '的', '温度'],
#  ['能', '不能', '将', '5', '点', '的', '闹钟', '修改', '成', '6', '点'],
#  ['动漫', '第', '10', '集帮', '我', '找', '一下', '吧'],
#  ['回答', '我能', '不能', '订', '一张', '去', '天津', '的', '机票'],
#  ['在', '中央', '人民', '广播', '里面', '找', '千里', '共', '良宵'],
#  ['设定', '8', '点上', '毛', '的', '闹钟'],
#  ['1', '月', '18', '日', '是', '农历', '几月', '几号'],
#  ['现在', '把', '空气', '净化器', '设置', '成', '高速', '模式', '行嘛'],
#  ['快点', '帮', '我', '查查', '礼拜', '几是', '4', '月', '的', '17', '日'],
#  ['这时候', '不想', '吹', '风扇', '了', '，', '帮', '我', '关掉'],
#  ['我', '想', '看', '阳光', '之下', '的', '第', '12', '集'],
#  ['南昌', '明天', '会', '降雨', '吗'],
#  ['夏天', '的', '道', '找', '过去', '听听'],
#  ['给', '我', '搜索', '2017', '年', '有', '关于', '讲解', '韩信', '的', '游戏', '视频'],
#  ['主持', '的', '经济', '之声', '收听', '一下', '可以', '吗'],
#  ['播放', '日语', '的', '物语'],
#  ['请', '给', '我', '来', '一首', '吴亦凡', '的', '英文歌', 'July', '。'],
#  ['这', '周二', '韶关', '的', '空气质量', '怎么样'],
#  ['春节', '是', '星期', '几'],
#  ['多少', '月', '多少', '号', '是', '农历', '的', '2', '月', '12'],
#  ['放', '了', '些', '，', '帮', '我', '把', '冰箱', '变温', '抽屉', '调', '到', '珍品', '档'],
#  ['找', '岁月', '就', '主播', '是', '的', '那个'],
#  ['我要', '听', '广播', '的'],
#  ['我', '现在', '就', '空调'],
#  ['播放', '一个', '韩剧', '窥探', '吧'],
#  ['循环', '播放', '张哲瀚', '的', '环绕', '吧'],
#  ['洛阳', '明天', '的', '温度', '会', '吗', '？'],
#  ['麻烦', '开启', '人体', '传感器'],
#  ['请', '看', '下', '从', '北京', '出发', '去往', '上海', '的', '规划'],
#  ['放', '一个', '频率', '是', '九', '七点', '四', '的', '先', '听', '为', '快'],
#  ['星期', '几是', '母亲节'],
#  ['循环', '播放', '近', '一周', '的', '香港', '湿度', '情况'],
#  ['酥油花', '灯节', '是', '什么', '哪', '天'],
#  ['给', '我', '打开', '胡歌演', '的', '的', '第二十一', '集'],
#  ['设定', '凌晨', '3', '点', '给', '宝宝', '冲', '奶粉'],
#  ['明天', '上海', '还是', '会', '下雨', '吗'],
#  ['我', '想', '看', '2021', '年谍', '战', '电视剧', '风暴', '舞', '幕后', '故事'],
#  ['电视剧', '，', '杨幂', '主演', '的', '亲爱', '的'],
#  ['播放', '汕头', '紫外线', '变化'],
#  ['1', '点', '5', '倍速', '播', '和', '演', '的', '独孤', '天下'],
#  ['重庆',
#   '之声',
#   '的',
#   '周末',
#   '快乐',
#   '听',
#   '着',
#   '太',
#   '快乐',
#   '了',
#   '，',
#   '现在',
#   '我要',
#   '听',
#   '这个',
#   '快乐'],
#  ['立即', '查看', '综艺', '向往', '的', '生活'],
#  ['开启', '空气', '净化器', '睡眠', '模式'],
#  ['请', '告诉', '我下', '现在', '空调', '是', '多少度', '哇'],
#  ['调低', '把', '我', '的', '空调', '温度', '调低', '些'],
#  ['客厅', '的', '空调', '调低', '到', '28'],
#  ['能', '告诉', '我', '明天', '紫外线', '强', '么'],
#  ['能', '继续', '收听', '汕头', '人民', '广播电台', '音乐台', '吗'],
#  ['深圳', '文艺', '电台', '第二台', '继续', '给', '我', '收听', '一下', '吧'],
#  ['收听', '频率', '是', '一零', '三点', '三', '的', '徐州', '人民', '广播电台', '文艺', '台'],
#  ['请', '播放', '带', '戏曲', '的', '专辑', '，', '李玉刚', '版', '的'],
#  ['可以', '播放', '一部', '10', '年代', '出版', '的', '海蒂', '和', '爷爷', '吗', '？'],
#  ['今天', '会', '下雪', '吗', '，', '晚点', '一起', '堆雪人', '吗'],
#  ['给', '我', '找', '一个', '美剧', '偶像剧', '播放', '一下', '吧'],
#  ['13', '号', '去', '江门', '穿', '什么', '衣服'],
#  ['民族', '大学', '怎么', '开车', '过去'],
#  ['帮', '我', '打开', '加湿器'],
#  ['鱼',
#   '已经',
#   '准备',
#   '好',
#   '了',
#   '，',
#   '帮',
#   '我',
#   '把',
#   '蒸',
#   '烤机',
#   '的',
#   '纯蒸',
#   '模式',
#   '开启',
#   '吧'],
#  ['我要', '听', '频率', '是', '一零', '五点', '六', '的', '助眠', '电台'],
#  ['将', '明天', '上午', '的', '闹钟', '全部', '删除'],
#  ['给', '我', '放', '一下', '文艺类', '的', '徐州', '人民', '广播电台', '文艺', '台'],
#  ['给', '我', '来', '一个', '韩国', '女神', '李', '知恩', 'iu', '唱', '的', '音乐', '视频', '吧'],
#  ['可以', '提醒', '我', '周六', '是', '小丽', '的', '生日', '吗'],
#  ['农历', '的', '7', '初', '19', '是', '星期', '几'],
#  ['打开', '搜狐', '视频', '我', '想', '看', '在', '桃花', '盛开', '的', '地方'],
#  ['查', '一下', '长春', '到', '山海关', '的', '汽车票'],
#  ['能', '不能', '帮', '我', '设置', '连续', '60', '天', '提醒', '我发', '朋友圈'],
#  ['有', '石鑫', '的', '节目', '吧', '就', '听', '会儿', 'I', '的', '能量', '吧'],
#  ['大后天', '是', '几号'],
#  ['能', '给', '我', '看', '那个', '玄幻剧', '档案', '吗'],
#  ['给', '我', '找', '北京', '体育', '广播', '的', '加速', '版', '在', 'FM102', '点', '5'],
#  ['频率', '是', '一零', '零点', '五', '的', '人民', '广播电台', '收听', '一下', '吧', '给', '我'],
#  ['播', '电台节目', '主持', '的', '雨天'],
#  ['顶楼', '播放', '一下', '可以', '吗'],
#  ['今天', '是', '5', '号', '明天', '是', '几号'],
#  ['帮',
#   '我',
#   '看一看',
#   '农历',
#   '7',
#   '月',
#   '18',
#   '和',
#   '农历',
#   '7',
#   '月',
#   '19',
#   '哪天',
#   '是',
#   '9',
#   '月',
#   '2',
#   '号',
#   '啊'],
#  ['我', '是', '特种兵', '这个', '战争片', '立刻', '放给', '我'],
#  ['2019', '年', '男篮', '世界杯', '巴西', '对', '希腊', '的', '比赛', '视频'],
#  ['回忆', '一下', '上', '周六', '海淀', '是', '雨天', '吗'],
#  ['请', '接着', '给', '我续', '放', '海洋', '的', '下雨天', '电台节目'],
#  ['一定', '循环', '播放', '我们', '的', '时光', '这首', '流行'],
#  ['2014', '年', '的', '奇缘', '可以', '播放', '下', '给', '我', '不'],
#  ['帮', '我查', '一下', '明年', '国庆节', '是', '星期', '几'],
#  ['将', '9', '点', '和', '12', '点', '的', '闹铃', '删除'],
#  ['呼吸', '的', '歌曲', '随便', '来', '一首', '播放', '一下', '吧'],
#  ['法语', '歌曲', '可以', '随机', '来', '一首', '不'],
#  ['下周一', '中山', '那儿', '有没有', '可能', '下', '大暴雨'],
#  ['可以', '随机', '给', '我', '来', '一曲', '山河', '令', '电视剧', '里面', '的', '歌', '呢'],
#  ['给', '我', '找', '一趟', '株洲', '去', '的', '最', '便宜', '的', '汽车票', '价格', '。'],
#  ['打开', '音响', '，', '让', '它', '自动播放', '轻快', '的', '音乐'],
#  ['我', '想', '看', '蜡笔小新', '第二季', '的', '和', '爸爸'],
#  ['想',
#   '看',
#   '一下',
#   '今天',
#   '的',
#   '南海',
#   '海洋',
#   '天气预报',
#   '，',
#   '给',
#   '我',
#   '调到',
#   '南海',
#   '吧'],
#  ['可以', '帮', '我', '把', '蒸', '烤箱', '切换', '到', '功能', '不'],
#  ['演', '的', '立刻', '播放'],
#  ['帮', '我', '把', '冰箱', '冷冻室', '的', '温度', '调', '到', '零下', '25', '度', '吧'],
#  ['设置', '一个', '今天下午', '6', '点', '的', '做饭', '的', '闹钟'],
#  ['11', '天', '之后', '提醒', '我', '给', '我', '妈'],
#  ['每天', '7', '点', '的', '那个', '提醒', '关掉', '吧'],
#  ['章子怡', '的', '电视剧', '的', '幕后', '花絮', '放', '来看', '一下'],
#  ['开封', '这', '15', '的', '穿衣', '指数', '怎么样', '呢'],
#  ['你', '给', '我定', '一个', '星期六', '下午', '六点', '的', '闹钟'],
#  ['能',
#   '不能',
#   '给',
#   '我',
#   '重新',
#   '播放',
#   '2012',
#   '年',
#   '伦敦',
#   '奥运会',
#   '米',
#   '游泳',
#   '孙杨',
#   '击败',
#   '霍顿',
#   '夺冠',
#   '的',
#   '视频'],
#  ['给', '我', '找个', '雨果', '的', '小说', '来放'],
#  ['天气', '好', '干', '，', '湿度器', '升到', '70', '吧'],
#  ['明天', '10', '点', '闹钟', '你', '给', '我定', '好了吗'],
#  ['五一', '下午', '2', '点去', '王府井', '逛街', '的', '闹钟', '定', '一下', '。'],
#  ['能',
#   '不能',
#   '给',
#   '我',
#   '播放',
#   '一下',
#   '2021',
#   '世界',
#   '女排',
#   '联赛',
#   '土耳其',
#   '对',
#   '的',
#   '比赛',
#   '视频'],
#  ['立即', '告诉', '我', '明天', '的', '农历', '是', '多少', '啊'],
#  ['明天', '上午', '所有', '的', '闹钟', '你', '帮', '我', '打开', '了', '吗'],
#  ['去查', '一查', '开来', '的', '磁悬浮列车', '是', '今天', '的', '吗'],
#  ['90', '年代', '比较', '搞笑', '的', '歌曲', '来', '一些', '听听'],
#  ['把', '抽烟', '机', '的', '档位', '调大', '一些'],
#  ['能', '把', '去', '海边', '的', '最快', '路线', '给', '我', '吗'],
#  ['查询', '台湾', '的', '空气质量', '怎么样'],
#  ['哎', '空调', '冷风', '给', '我', '打开'],
#  ['现在', '请', '播放', '的', '悬疑', '小说', '无罪', '谋杀'],
#  ['可以', '查询', '到', '的', '高铁', '是', '几点', '的', '吗'],
#  ['请', '给', '我', '调出', '幺', '零', '零点', '七', '的', '江都', '人民', '广播电台'],
#  ['放', '一首', '扬琴', '版', '的'],
#  ['明天', '深圳', '会下', '冰雹', '吗'],
#  ['帮', '我', '把', '热水器', '温度', '调到', '50', '度', '吧'],
#  ['告诉', '我', '什么', '时候', '是', '清明节'],
#  ['我', '需要', '你', '提醒', '我', '7', ':', '10', '出门'],
#  ['后天', '的', '农历', '是', '几号'],
#  ['播放', '美国', '电影', '奇缘'],
#  ['给', '我', '找出', '5', '月', '27', '日', '17', '点', '播出', '的', '动漫'],
#  ['我', '想', '听', '主持', '的', 'FM103.9'],
#  ['搜索', '明天', '山东', '会', '下雨', '吗'],
#  ['现在', '就', '想', '查查', '下个月', '二十', '号', '是不是', '父亲节'],
#  ['给', '我', '找', '一首', '的', '歌', '听听'],
#  ['开启', '明天', '10', '点', '35', '分', '的', '闹钟'],
#  ['频率', '是', '一零', '一点', '零', '的', '广东', '可以', '继续', '收听', '吗'],
#  ['我', '想', '播放', '张信哲', '的', '下', '一个', '永远', '中', '的'],
#  ['广播剧', '默读', '的', '预告', '帮', '我', '播放'],
#  ['播放', '欧美', '动漫', '超人'],
#  ['能否', '将', '17', '点', '40', '的', '闹钟', '修改', '成', '16', ':', '20'],
#  ['我', '想', '打开'],
#  ['我要', '看', '大陆', '片', '我', '的', '姐姐', '这个', '电影'],
#  ['帮', '我', '找', '一个', '做', '的', '视频'],
#  ['是不是', '能', '播放', '一个', '剧情片', '奇妙', '的', '命运', '呀'],
#  ['你', '知道', '阴历', '5', '月', '22', '是', '阳历', '几号'],
#  ['查询', '下周', '甘肃', '气温', '会', '逐渐', '升高', '吗'],
#  ['能', '继续', '播放', '美国', '那个', '电视剧', '吗'],
#  ['有点', '冷', '啊', '空调', '帮', '我', '关掉'],
#  ['能',
#   '不能',
#   '来',
#   '一个',
#   '频率',
#   '是',
#   '九九',
#   '点',
#   '一',
#   '的',
#   '山东',
#   '文艺',
#   '广播电台',
#   '呢'],
#  ['帮', '我', '搜索', '一些', '音乐', '电台'],
#  ['收听', '文艺类', '的', '山东', '文艺', '广播电台'],
#  ['今天天气', '，', '我', '想', '拍照', '，', '帮', '我', '把', '摄像机', '设置', '拍', '模式', '吧'],
#  ['后天', '有', '过来', '不会', '降温', '不'],
#  ['坐', '几路', '到', '万达', '广场', '西门', '啊'],
#  ['我', '想', '收听', '频率', '是', '九', '三点', '四', '的', '晚安', '电台'],
#  ['今天', '10', '点', '的', '闹钟', '我', '现在', '想要', '你', '给', '我'],
#  ['北京', '开往', '上海', '的', '特快', '列车', '进站', '了', '吗'],
#  ['把', '电扇', '的', '风速', '调大', '一些', '太热', '了'],
#  ['能', '收到', '的', '日语', '电台', '给', '我', '随便', '拨', '一个'],
#  ['查查', '昨天', '应该', '是', '什么', '节日'],
#  ['现在', '告诉', '我', '长沙', '去往', '拉萨', '的', '动车', '今天', '有', '吗'],
#  ['开始', '播放', '北京', '音乐', '广播', '的', '英文歌'],
#  ['9', '月', '9', '是', '什么', '节'],
#  ['湖南', '五天', '后', '有', '台风', '吗'],
#  ['现在', '还是', '想', '继续', '看', '下', '一站', '幸福', '呢'],
#  ['今天', '播放', '最火', '的'],
#  ['今天下午', '三点', '的', '提醒', '定好', '了', '么'],
#  ['查询', '纽约', '近期', '的', '温度'],
#  ['查看', '查看', '后天', '12', '点去', '广州', '的', '二等', '座', '还有', '吗'],
#  ['告诉', '他', '知道', '深圳', '去往', '丽江', '的', '动车', '今天', '有', '吗'],
#  ['播放', '5', '月', '16', '号', '上午', '10', '点', '的', '英雄', '联盟', '竞技', '赛', '视频'],
#  ['动漫', '帮', '我', '找', '一下', '吧'],
#  ['想', '听', '最好', '的', '都', '给', '你', '了', '，', '给', '我', '唱'],
#  ['请', '给', '我', '播放', '2016', '年', '美国', '电视剧', '第四季', '花絮'],
#  ['比赛', '的', '视频', '帮', '我', '找', '一下'],
#  ['今天下午', '3', '点', '的', '提醒', '改', '下'],
#  ['能', '给', '我', '来', '一个', '2021', '年', '的', '古典音乐', '不', '呢'],
#  ['想',
#   '听',
#   '英文',
#   '专辑',
#   '了',
#   '，',
#   '就',
#   '第',
#   ' ',
#   'with',
#   ' ',
#   'you',
#   '吧',
#   '，',
#   '林俊杰',
#   '的'],
#  ['能', '播放', '一下', '有', '范冰冰', '出演', '的', '电视剧', '秦始皇', '么'],
#  ['郑州', '上', '月', '下雪', '了', '吗'],
#  ['请问', '一下下', '周日', '是', '几号'],
#  ['东营', '生活', '广播节目', '给', '我', '放', '一下'],
#  ['去年', '的', '谷雨', '是', '周几'],
#  ['帮', '我', '搜索', '一下', 'CCTV2', '的'],
#  ['去年', '台湾', '有个', '都市', '片', '，', '奇幻', '题材', '的', '帮', '我', '播放'],
#  ['立即', '设置', '一个', '9', '点', '提醒', '我', '关灯', '的', '闹铃'],
#  ['从', '回', '学校', '的', '几条', '路线', '中', '找', '一条', '最优', '的', '给', '我'],
#  ['完美', '播放', '，', '他们', '合唱', '的'],
#  ['我', '明天', '下午', '的', '闹钟', '取消'],
#  ['找到', '之声', '的', '故事会', '听听'],
#  ['我', '想', '知道', '下午', '2', '点有', '重庆', '始发', '到', '济南', '的', '动车', '吗'],
#  ['这个', '空调', '温度', '太高', '了', '，', '调低', '一点儿'],
#  ['西藏', '后天', '晚上', '八点', '会', '下雪', '吗', '？'],
#  ['港片', '新', '喜剧之王', '播放', '一下', '可以', '吗'],
#  ['请', '不要', '忘记', '通知', '我', '在', '5', '月', '30', '号', '去', '打', '狂犬', '疫苗'],
#  ['随机', '播放', '一首', '纯音乐', '。'],
#  ['小猪', '佩奇', '是', '美国', '的', '吗', '播放', '一下', '看看'],
#  ['将', '空调', '切换', '到', '省', '电', '模式', '行不行', '呢'],
#  ['我', '想', '查看', '北京', '未来', '的', '天气'],
#  ['取消', '今天', '晚上', '9', '点', '的', '那个', '提醒'],
#  ['告诉', '我', '后天', '12', '点去', '广州', '的', '火车票', '还有', '吗'],
#  ['开启', '水浸', '传感器'],
#  ['能', '不能', '给', '我订', '一张', '大理', '飞', '北京', '的', '航班', '头等舱', '票'],
#  ['明天', '兴义', '吗'],
#  ['能', '不能', '播放', '一个', '1999', '年', '拍', '的', '电视剧', '啊'],
#  ['立刻', '新建', '一个', '备忘录', '3', ':', '50', '提醒', '我'],
#  ['每', '周末', '上午', '游泳', '，', '闹钟', '叫', '我'],
#  ['的', '城市', '声音', '帮', '我', '播放', '一下'],
#  ['上午',
#   '电视',
#   '演',
#   '的',
#   '的',
#   '都市',
#   '朋友圈',
#   '都',
#   '讲',
#   '了',
#   '些',
#   '什么',
#   '我',
#   '想',
#   '看',
#   '下'],
#  ['5', '月', '27', '解说', '更新', '了', '吞噬', '大', '僵尸', '的', '游戏', '视频', '吗'],
#  ['把', '空调', '风速', '调大', '再', '调大'],
#  ['给', '我', '放', '这', '一部', '爱情', '类', '电影', '。'],
#  ['4', '月', '10', '日', '和', '4', '月', '9', '日', '哪天', '是', '星期三'],
#  ['创建', '一个', '周六', '晚上', '8', '点', '跟', '朋友', '去', '看', '电影', '的', '闹钟', '。'],
#  ['星期天', '下午', '3', '点', '的', '时候', '不要', '再', '提醒', '我', '看', '风暴'],
#  ['4',
#   '月',
#   '25',
#   '日',
#   '讲解',
#   '的',
#   '兰陵王',
#   '怒',
#   '孙悟空',
#   '的',
#   '游戏',
#   '视频',
#   '可以',
#   '给',
#   '我',
#   '找',
#   '一下',
#   '吗'],
#  ['请', '按', '随机', '播放', '一首', '张杰', '的', '中文歌曲'],
#  ['我', '想', '看', '、', '执导', '的', '我', '怕', '来不及'],
#  ['夜晚',
#   '听',
#   '老',
#   '谭',
#   '的',
#   '老',
#   '谭',
#   '讲故事',
#   '很',
#   '不错',
#   '，',
#   '在',
#   '杭州',
#   '新闻广播',
#   '播放'],
#  ['给', '我', '放', '一下', '的', '篮球比赛', '视频'],
#  ['这', '几天', '香港', '穿衣', '适合', '啥'],
#  ['给',
#   '我',
#   '找到',
#   '陕西',
#   '戏曲',
#   '广播',
#   '按',
#   '时间',
#   '顺序',
#   '播放',
#   '里面',
#   '的',
#   '花鼓戏',
#   '节目'],
#  ['把', '电扇', '风速', '到', '最大'],
#  ['找到', '美国', '的', '科幻', '大片', '给', '我', '看', '一个', '可以', '吗'],
#  ['听', '一下', '英文歌', ' ', '给', '我', '找', 'FM88', '点', '7'],
#  ['今年', '的', '那达慕', '什么', '时候', '举行'],
#  ['今晚', 'AG', '有没有', '直播', '王者', '荣耀'],
#  ['播', '一首', '运动', '风格', '的', '中文歌曲'],
#  ['赶快', '帮', '我', '播放', '江苏', '新闻广播', '的', '电台节目', '高爽', '说法'],
#  ['看', '一眼', '去往', '南平', '的', '动车', '哪天', '有票', '啊'],
#  ['快给我', '查询', '最快', '去', '一班', '长春', '去', '上海', '的', '机票', '还有', '几张'],
#  ['嗯', '呐', '朱莉', '主演', '的', '电视剧', '朱莉', '播放', '给', '我', '看看', '可以', '吗'],
#  ['查', '一下', '武汉', '至', '成都', '的', '机票价格', '。'],
#  ['建立', '提醒', '5', '月', '19', '号', '上网', '课'],
#  ['来', '一个', '战争片', '给', '我', '吧'],
#  ['香港', '降雨', '情况', '怎么样'],
#  ['马上', '瞅', '瞅', '几月', '几号', '是', '建党', '节'],
#  ['打开',
#   '腾讯',
#   '视频',
#   '把',
#   '昨天',
#   '放',
#   '的',
#   '奔跑',
#   '吧',
#   '兄弟',
#   '再',
#   '给',
#   '我',
#   '重播',
#   '一遍'],
#  ['我要', '听', '北京', '交通广播', '的', '1039', '交通', '服务', '热线'],
#  ['赶紧', '说', '说', '几月', '几号', '是', '这个', '周一', '呢'],
#  ['帮忙', '帮', '冰箱', '开启', '节能', '模式'],
#  ['给', '我', '搜索', '一下', '沈腾演', '的', '综艺', '王牌', '对', '王牌', '第', '6', '季'],
#  ['立即', '搜索', '保定', '紫外线', '指数'],
#  ['现在', '看', '美国', '的', '吸血鬼', '日记'],
#  ['给', '查找', '南京', '飞往', '悉尼', '的', '航班', '哪天', '有票'],
#  ['给', '我', '一下', '我', '前面', '看', '的', '言情剧', '呢'],
#  ['播放', '一下', '频率', '是', '一零', '五点', '六', '的', '人民', '广播电台'],
#  ['今年', '的', '是', '几月', '几号'],
#  ['看看', '8', '号', '上海', '是不是', '要', '下雨', '呢'],
#  ['查询', '星期三', '是', '什么', '节日', '呢'],
#  ['今天下午', '降雨量', '多少'],
#  ['以后', '不用', '每天', '提醒', '我', '学习', '了'],
#  ['周二', '乌鲁木齐', '吧', '？'],
#  ['里面', '的', '歌', '可以', '随机', '唱', '一首', '吗'],
#  ['我', '想', '立刻', '观看', '一个', '日本', '的', '喜剧', '，', '古代', '的'],
#  ['创建', '明天', '晚上', '9', '点', '看', '直播', '的', '日程'],
#  ['查询', '大理', '周日', '会', '大面积', '降雨', '吗'],
#  ['放', '一下', '的', '第', ' ', '179', '集', '我', '想', '看'],
#  ['为', '我', '播放', '演播', '中国', '乡村', '之声', '的', '乡村', '夜话'],
#  ['3',
#   '月',
#   '18',
#   '日',
#   '那天',
#   '电影台',
#   '有',
#   '啥',
#   '电影',
#   '好看',
#   '，',
#   '帮',
#   '我',
#   '看',
#   '下'],
#  ['王者', '荣耀', '的', '比赛', '视频', '给', '我', '找', '一下'],
#  ['可以', '在', '搜狐', '上', '播放', '吧'],
#  ['我', '想', '听', '音乐', '之声', '广播'],
#  ['查', '一下', '今天', '南京', '的', '最高', '气温'],
#  ['请',
#   '把',
#   '7',
#   '月',
#   '10',
#   '号',
#   '到',
#   '7',
#   '月',
#   '29',
#   '号',
#   '的',
#   '日程',
#   '全部',
#   '删除'],
#  ['请', '重听', '频率', '是', '一零', '五点', '三', '的', '盐城', '人民', '经济', '台'],
#  ['南京', '怎么', '走', '，', '为', '我', '导航', '一下', '啦'],
#  ['我要', '看', '经济', '类', '的', '经济', '之声'],
#  ['海上', '戏剧', '麻烦', '帮', '我', '找', '一下'],
#  ['我', '想', '看', '2017', '年', '的', '贪吃蛇', '大', '作战', '的', '游戏', '解说', '视频'],
#  ['放', '一个', '欧阳', '娜娜', '的', '电视剧', '幕后', '花絮'],
#  ['查', '一下', '到', '洛杉矶', '的', '机票'],
#  ['甄子丹', '刘德华', '演', '的', '追龙', '现在', '给', '我', '放'],
#  ['查询', '杭州', '的', '紫外线', '这', '几天', '高', '么'],
#  ['星期', '几是', '国庆节'],
#  ['给', '我', '播放', '一个', '韩国', '2021', '年', '的', '电视剧', '可以', '吗'],
#  ['播放', '香格里拉', '最新', '的', '紫外线', '指数'],
#  ['给', '我', '回放', '5', '月', '21', '日', '的', '奔跑', '吧', '第', '5', '季', '精彩'],
#  ['查询', '明天', '江苏', '会', '大面积', '降雨', '吗'],
#  ['帮', '我', '创建', '后天', '中午', '两点', '取', '快递', '的', '日程'],
#  ['给', '我', '播放', '一个', '法国', '纪录片', '吧'],
#  ['快点', '告诉', '我', '一下', '始发', '的', '动车', '哪天', '有票'],
#  ['你', '在', '早上', '九点', '的', '时候', '提醒', '电话卡'],
#  ['我要', '看', '大陆', '片', '横空出世', '这个', '电影'],
#  ['林俊杰', '的', '专辑', '乐行者', '随机', '播放', '吧'],
#  ['看看', '九月', '有', '流星雨', '的', '那天', '是', '几号'],
#  ['设置', '一个', '明天', '早上', '9', '点去', '参加', '朋友', '婚礼', '的', '闹钟', '。'],
#  ['赶紧', '告诉', '我', '农历', '5', '月', '5', '是', '什么', '节日'],
#  ['今天', '需要', '洗', '衣物', '，', '帮', '我', '切换', '到', '洗', '吧'],
#  ['马上', '就让', '我', '知道', '汉堡', '始发', '的', '飞机', '是', '几点', '的', '呢'],
#  ['你', '现在', '就', '告诉', '我', '答案', '几月', '几号', '是', '这个', '啊'],
#  ['南京', '紫外线', '强', '吗'],
#  ['请', '播放', '中央人民广播电台', '的', '经济', '之声'],
#  ['讲', '一下', '的', '故事', '英文版', '的'],
#  ['提醒', '我', '周日', '上午', '8', '点去', '交'],
#  ['6', ':', '25', '提醒', '我', '去', '拿', '删除', '这个', '提醒'],
#  ['不要', '忘', '了', '在', '18', '点半', '提醒', '我', '打', '微信', '电话', '给', '小明'],
#  ['放', '一个', '的', '翻唱', '视频', '看'],
#  ['动漫', '第一季', '帮', '我', '找', '一下', '吧'],
#  ['治愈', '系', '的', '钢琴曲', '能', '随便', '来个', '听', '吗'],
#  ['给', '我', '来', '一个', '拍摄', '我', '只', '喜欢', '你', '的', '现场', '花絮'],
#  ['给', '我', '准备', '今年', '甘肃', '的', '降水量'],
#  ['查下', '盐城', '未来', '三天', '的', '天气'],
#  ['继续', '看', '一会', '宫斗剧', '如懿传', '可以', '吗'],
#  ['告诉', '我', '台湾', '这周', '有', '台风', '吗'],
#  ['六一', '儿童节', '的', '农历', '是', '几号'],
#  ['今天', '4', '点', '40', '的', '闹钟', '帮', '我', '删除'],
#  ['空调', '风速', '要', '最高', '最强'],
#  ['准时', '收听', '的', '快乐', '早点', '到'],
#  ['明天', '一定', '要', '记得', '提醒', '我', '买'],
#  ['能', '不能', '播放', '一个', '李易峰', '的', '古装剧', '看看', '，', '除了', '古剑', '之外'],
#  ['播放', '刘谦', '在', '2018', '年春', '晚上', '魔术', '表演', '的', '视频'],
#  ['顺序', '播放', '李健', '的', '歌曲'],
#  ['1999', '年', '发行', '的', '歌', '都', '播放', '一遍', '呢'],
#  ['随机', '来', '一首', '欢快', '一点', '的', '浪漫', '情歌', '吧'],
#  ['我', '需要', '你', '播放', '犯罪', '电视剧', '第一部'],
#  ['来', '一首', '差', '一步', '里', '的', '歌儿'],
#  ['设置', '20', '号', '上午', '看', '车展', '的', '闹钟'],
#  ['19', '点有', '珠海', '始发', '去', '汕头', '的', '长途车', '不'],
#  ['帮',
#   '我',
#   '创建',
#   '一个',
#   '12',
#   '号',
#   '上午',
#   '9',
#   '点',
#   '参加',
#   '姥姥',
#   '的',
#   '生日',
#   '的',
#   '闹钟',
#   '。'],
#  ['到', '怎么', '走'],
#  ['七点', '我', '想', '看', '一下', '18', '年', '岳云鹏', '孙越', '爆笑', '相声', '合辑'],
#  ['把', '空调', '调高', '10', '度', '可以', '吗'],
#  ['播放', '欧美', '动漫', '精灵'],
#  ['可以', '播放', '郑凯演', '的', '吧'],
#  ['怎么', '到', '世纪', '城', '啊'],
#  ['石家庄', '今天', '最高', '几度'],
#  ['播放', '一首', '应景', '儿', '的', '《', '回到', '拉萨', '》', '，', '我要', '的'],
#  ['动作片', '李冰冰', '主演', '的', '风声'],
#  ['FM103', '点', '7', '的', '中国', '之', '声调', '那里', '去'],
#  ['银临', '、', '河图', '的', '专辑', '播放'],
#  ['3', '月', '10', '号', '下午', '三点', '的', '提醒', '请', '不要', '提醒', '我'],
#  ['今天', '到', '武汉', '来不及', '了', '，', '找', '一个', '明天', '最早', '的', '高铁'],
#  ['给', '我播', '一下', '的', '电台节目'],
#  ['告诉', '我', '大前天', '是', '农历', '多少'],
#  ['我', '想', '听', '的', '爱', '的', '这首', '流行音乐'],
#  ['今年', '的', '愚人节', '是', '什么', '时候'],
#  ['岳阳', '明天', '会', '下雨', '吗', '？'],
#  ['想带', '孩子', '出去玩', '今天', '杭州', '天气', '如何'],
#  ['我', '需要', '你', '来', '一首', '许嵩', '的', '认错', '呢'],
#  ['六月', '末', '穿', '裙子', '去', '会', '冷', '吗'],
#  ['我要', '听', '北京', '人', '名', '广播电台', '音乐台'],
#  ['韩国', '2015', '年', '上', '的', '电影', '给', '我', '播放', '一下', '吧'],
#  ['狐', '妖', '小', '红娘', '播放', '动漫', '类', '的'],
#  ['大后天', '大同', '是', '的', '天气', '吗'],
#  ['今天', '更新', '的', '4', '的', '相关', '视频', '放', '一个', '哈'],
#  ['想', '去', '，', '这', '周末', '天气', '怎么样', '呢', '？'],
#  ['听', '一个', '主持', '的', '毛泽东', '的', '故事'],
#  ['我', '想', '你', '帮', '我', '记住', '5', '月', '22', '号', '是', '我', '妈妈', '生日'],
#  ['我',
#   '想',
#   '看',
#   '2021',
#   '年',
#   '世界',
#   '女排',
#   '联赛',
#   '中国女排',
#   'VS',
#   '韩国',
#   '女排',
#   '的',
#   '比赛',
#   '视频'],
#  ['我',
#   '准备',
#   '看',
#   '电影',
#   '了',
#   '，',
#   '把',
#   '灯',
#   '调暗',
#   '一些',
#   '，',
#   '调',
#   '到',
#   '观影',
#   '模式',
#   '。'],
#  ['雨天', '在', '丽江', '骑车', '可以', '吗'],
#  ['下周一', '早上', '9', '点去', '的', '经济舱', '。'],
#  ['明天', '紫外线', '怎么样'],
#  ['游泳池', '打开'],
#  ['今年', '的', '中秋节', '是', '九月', '几日'],
#  ['开车', '走', '国道', '的', '去', '福州', '该', '怎么', '走', '告诉', '我', '一下', '呗'],
#  ['近期', '山东', '穿衣', '指数', '如何'],
#  ['9', '月', '15', '号', '是', '星期', '几', '啊'],
#  ['把', '风速', '开到', '6', '了', '吧', '空调', '的'],
#  ['找', '一下', '每周三', '，', '20', '点', '更新', '的', '国产', '动漫'],
#  ['我', '想', '连', '着', '上次', '看', '的', '那个', '迪丽', '热巴', '的', '那个', '剧看'],
#  ['你', '好好', '给', '我', '看看', '蚌埠', '始发', '的', '高铁', '是', '7', '点', '的', '吗'],
#  ['音乐', '类', '的', '魅力', '103', '来', '听听'],
#  ['后天', '有风', '吗', '公主岭', '这里'],
#  ['中华', '之声', '播放', '，', '就是', '主持', '的', '那个'],
#  ['帮', '我', '把', '电饭煲', '调', '成', '煮饭', '模式', '。'],
#  ['查询', '中国', '的', '阴历', '正月', '19', '日', '是', '星期', '几', '呢'],
#  ['只', '打开', '今天下午', '的', '闹钟'],
#  ['找出', '5', '月', '27', '日', '22', '点', '播出', '的', '动漫'],
#  ['我要', '陈', '小熊', '的', '歌儿', ' ', '济南', '济南', '吧'],
#  ['请', '播放', '的', '《', '梅兰', '梅兰', '我爱你', '》'],
#  ['看', '一下', '4', '月', '21', '日', '是', '阴历', '多少'],
#  ['进', '播放', '的', '三十', '集', '风暴', '舞'],
#  ['空调', '风速', '调', '高', '百分之', '25'],
#  ['找', '陈奕迅', '2020', '年', '在', '上海', '的', '演唱会', '视频', '来放'],
#  ['能', '帮', '我', '把', '空调', '温度', '调到', '22', '度', '吗'],
#  ['美国', '的', '大蒜', '节是', '几月', '几号'],
#  ['请', '播放', '由', '张子枫', '主演', '的', '电影', '我', '的', '姐姐', '。'],
#  ['厦门', '飞往', '洛杉矶', '的', '航班', '明天', '有票', '不'],
#  ['继续', '播放', '琉璃', '第', '10', '集', '之后', '的', '剧集'],
#  ['明天', '12', '点飞', '北京', '的', '机票', '还有', '没有', '了'],
#  ['增加', '一个', '早上', '11', ':', '30', '提醒', '的', '备忘录'],
#  ['上海', '这', '周末', '空气', '湿度', '多少'],
#  ['在', '13', ':', '30', '通知', '我', '关闭', '火影忍者'],
#  ['我', '忘记', '关', '电脑', '了', '，', '帮', '我', '关掉', '它'],
#  ['明天', '能到', '15', '度', '吗'],
#  ['设置', '明天', '晚上', '10', '点上', '淘宝', '抢', '东西', '的', '闹钟', '。'],
#  ['是不是', '可以', '播放', '一下', '今年', '爱上', '男声', 'FM', '呢'],
#  ['放', '一首', '萨克斯', '演奏', '的', '古典音乐'],
#  ['播', '一下', '晚上', '20', '点', '更新', '的', '完美', '的', '他', '的', '介绍', '视频'],
#  ['我', '想', '听', '英文', '的', '情歌', '呢'],
#  ['能', '不能', '帮', '我', '报', '下星期', '几是', '农历', '的', '2', '月初', '1'],
#  ['到', '南阳', '怎么', '走', '啊'],
#  ['立即', '搜索', '玉田', '紫外线', '指数'],
#  ['立刻', '播放', '一下', '武藤兰', '的', '日本', '电视剧', '呢'],
#  ['跳', '的', '视频', '还有', '吗', '我', '有点', '想', '看'],
#  ['立即', '查看', '大连', '海边', '的', '风向', '和', '湿度'],
#  ['查询', '明天', '秦皇岛', '下', '大雨', '情况'],
#  ['查找', '国产', '动漫', '镇魂', '街', '第二季'],
#  ['顺序', '播放', '周杰伦', '的', '专辑', '七里香', '里面', '的', '歌'],
#  ['恶魔', '在', '身边', '台湾', '偶像剧', '1', '点', '25', '倍速', '播放'],
#  ['这', '一生', '关于', '你', '的', '风景', '，', '我要', '听', '隔壁', '的'],
#  ['元宵节', '在', '几月'],
#  ['提醒', '我', '周末', '下午', '5', '男友', '。'],
#  ['客厅', '的', '灯', '有点', '暗', '，', '帮', '我', '把', '灯', '调亮些', '吧'],
#  ['收听', '频率', '是', '八九点', '零', '的', '襄樊', '交通', '音乐台'],
#  ['我', '想', '你', '给', '我', '播放', '一首', '表达', '的', '钢琴曲', '呢'],
#  ['五大连池', '最近', '是', '晴天', '吗'],
#  ['5', '月', '30', '号', '3', ':', '10', '给', '我定', '个', '闹钟'],
#  ['长春', '气温', '会', '逐步', '升高', '吗'],
#  ['定', '周三', '早上', '8', '点', '的', '闹钟'],
#  ['播放', '欧美', '动漫', '联盟'],
#  ['给',
#   '我',
#   '找',
#   '一下',
#   '2021',
#   '年',
#   '央视',
#   '元宵',
#   '晚会',
#   '的',
#   '魔术',
#   '视频',
#   '放',
#   '来看'],
#  ['我', '想', '知道', '12', '月', '6', '日去', '米兰', '的', '经济舱', '价格', '。'],
#  ['单曲', '循环', '一下', '名', '侦探', '柯南', '里面', '的', '主题曲', '吧'],
#  ['明天', '中午', '12', '点', '跟', '朋友', '去', '吃饭', '的', '闹钟', '帮', '我定', '一下', '。'],
#  ['黄安', '90', '年代', '的', '歌', '随机', '来', '一首', '可以', '吗'],
#  ['是不是', '能', '帮', '我', '播放', '台湾', '艺人', '林心如', '的', '戏'],
#  ['规划', '一下', '到', '儿童医院', '的', '路线'],
#  ['帮', '我', '找到', '的', '路线'],
#  ['可以', '不', '可以', '把', '灯', '的', '亮度', '调', '高', '一点'],
#  ['查查', '明天', '的', '日历表', '是', '多少', '号'],
#  ['查', '一下', '明天', '青岛', '空气质量', '怎么样'],
#  ['三月初', '一', '妈妈', '生日', '的', '闹钟'],
#  ['狂欢节', '是', '周几'],
#  ['工作日', '早上', '9', '点', '的', '闹钟', '给', '我', '设置', '好', '了', '没有'],
#  ['设置', '星期日', '下午', '5', ':', '30', '的', '日程'],
#  ['明天', '湖南', '的', '温度', '怎么样'],
#  ['速度', '的', '让', '我', '知道', '开来', '的', '动车', '是', '今天', '的', '吗'],
#  ['来', '一个', '美国', '电影', '变形金刚', '1'],
#  ['周六', '我要', '去', '洛阳', '看', '，', '现在', '还', '能', '不能', '订', '汽车票', '到', '洛阳'],
#  ['2',
#   '月',
#   '4',
#   '日',
#   '开始',
#   '播放',
#   '的',
#   '年',
#   '的',
#   '还',
#   '在',
#   '更新',
#   '吗',
#   '我',
#   '想',
#   '看看'],
#  ['农历', '的', '中元节', '是', '周几'],
#  ['放', '一个', '主持', '的', '温暖', '的', '家'],
#  ['海淀', '风大', '吗'],
#  ['我要', '30', '秒', '后', '知道', '福州', '开往', '北京', '的', '高铁', '今天', '有票', '吗'],
#  ['二胡', '弹奏', '的', '人气', '高', '的', '歌曲', '来', '一首', '呢'],
#  ['长沙', '去往', '沈阳', '的', '动车', '哪天', '有票', '啊'],
#  ['有没有', '比较', '热血', '的', '动漫', '给', '我', '来', '一首', '吧'],
#  ['按', '顺序', '播放', '专辑', '里', '的', '歌曲'],
#  ['帮', '我', '打开', '智能', '闹钟', '，', '然后', '一下', '时间', '吧'],
#  ['现在', '能', '说', '说', '礼拜', '几是', '10', '月', '的', '10', '日', '吗'],
#  ['帮', '我', '找', '一下', '到', '超市', '的', '路'],
#  ['帮', '我', '播放', '班长', '殿下'],
#  ['北京', '今天', '空气', '怎么样', '还是', '什么'],
#  ['你', '现在', '可以', '给', '我建', '一个', '13', '号', '去', '医院', '的', '提醒', '么', '？'],
#  ['2000', '年', '左右', '的', '歌曲', '给', '我', '随机', '来', '一首'],
#  ['从', '拉萨', '到', '有没有', '客车', '去', '的'],
#  ['那个', '中国', '电视剧', '陈情', '令', '的', '花絮', '播放', '一下', '吧'],
#  ['播放', '的', '大约', '在'],
#  ['搜索', '附近', '的'],
#  ['走路', '怎么', '到', '大'],
#  ['遂溪', '人民', '广播电台', '给', '我', '连', '着', '上次', '听到', '的', '地方', '收听', '吧'],
#  ['查下', '日历', '后天', '的', '农历', '是', '几号'],
#  ['盐城', '最近', '昼夜', '温差', '大不大'],
#  ['空调', '可以', '调到', '18', '度', '吗'],
#  ['6', '月', '2', '号', '下午', '1', '点到', '6', '点', '的', '提醒', '并', '全部', '删除'],
#  ['享受', '蜻蜓', 'fm', '电台', '里', '的', '歌曲'],
#  ['周末', '两天', '分别', '是', '多少', '号'],
#  ['你', '能', '给', '我', '的', '快乐', '很', '简单', '吗'],
#  ['大陆', '的', '有关', '的', '电影', '能', '播放', '一个', '么'],
#  ['现在', '去', '银川', '就行', '吧'],
#  ['是不是', '能', '单曲', '循环', '一下', '你', '不', '知道', '的', '事'],
#  ['我要', '马上', '知道', '大后天', '是', '农历', '几', '月初', '几', '呢'],
#  ['加拿大', '的', '土拨鼠', '节是', '什么', '时候'],
#  ['可以', '帮', '我', '把', '空调', '切换', '到', '除湿', '模式', '吗'],
#  ['衣服', '有些', '了', '，', '帮', '我', '打开', '电熨斗', '。'],
#  ['帮', '我', '打开', '客厅', '的', '摄像头', '好', '吗'],
#  ['请', '继续', '播放', '美国', '权力', '的', '游戏', '的', '第二季'],
#  ['查询', '明天', '是不是', '晴天'],
#  ['放', '一下', '的', '经典', '岁月'],
#  ['找', '一部', '讲述', '美食', '的', '美国', '纪录片', '来看'],
#  ['我',
#   '想要',
#   '看',
#   '今年',
#   '刘',
#   '半仙',
#   '解说',
#   '的',
#   '迷你',
#   '世界',
#   '完整版',
#   '游戏',
#   '解说',
#   '视频'],
#  ['义务', '昨天', '下', '冰雹', '了', '吗'],
#  ['收听', '频率', '是', '一零', '七点', '八', '的', '励志', '电台'],
#  ['查询', '明早', '海淀', '降雪', '吗'],
#  ['明天', '江苏', '会', '下雨', '吗'],
#  ['明天', '沧州', '多地', '降雨', '吗'],
#  ['播放', '青春', '的', '大结局'],
#  ['随机', '来', '一首', '2011', '年', '的', '歌'],
#  ['今天', '太', '干燥', '了', '，', '帮', '我', '打开', '加湿器', '。'],
#  ['我要', '到', '去', '找', '下路'],
#  ['听', '一下', '张国荣', '光荣', '岁月', '里面', '的', '歌', '吧'],
#  ['还是', '想', '循环', '播放', '流行', '风格', '的', '专辑'],
#  ['放', '一首', 'rap', '，', '放'],
#  ['查询', '周五', '哈尔滨', '是', '晴天', '吗'],
#  ['帮', '我', '查查', '长沙', '去往', '哈尔滨', '的', '动车', '哪天', '有票', '啊'],
#  ['给', '我', '把', '空调', '调低', '温度'],
#  ['后天',
#   '下午',
#   '3',
#   '点',
#   '给',
#   '妈妈',
#   '做',
#   '皮肤',
#   '护理',
#   '的',
#   '闹铃',
#   '帮',
#   '我',
#   '开启',
#   '一下',
#   '吧',
#   '。'],
#  ['找', '一个', '汪峰', '2019', '年', '演唱会', '的', '视频'],
#  ['三亚', '飞', '巴黎', '的', '飞机', '哪', '天才', '有', '呢'],
#  ['找',
#   '一下',
#   '刘涛',
#   '在',
#   '2020',
#   '年',
#   '跨',
#   '年',
#   '晚会',
#   '上',
#   '唱歌',
#   '的',
#   '视频',
#   '来看'],
#  ['帮', '我', '把', '洗衣机', '切换', '到', '洗', '模式', '吧'],
#  ['开启', '烤箱', '的', '小', '烧烤', '功能', '呢'],
#  ['帮', '我', '找', '一个', '做', '干', '的', '视频'],
#  ['最近', '的', '一班', '到', '北京', '的', '火车', '是', '几点'],
#  ['查', '一下', '石家庄', '今天', '的', '最低温度', '啊'],
#  ['我', '想', '看', '赵薇', '90', '年代', '的', '剧'],
#  ['现在', '给', '我', '循环', '收听', '的', '交通', '新闻'],
#  ['查询', '周五', '衡水', '紫外线', '怎么样'],
#  ['查一查', '西宁', '发', '往', '北京', '的', '大巴', '明天', '有没有', '票'],
#  ['能', '不能', '帮', '我', '设置', '5', '月', '30', '号', '提醒', '我'],
#  ['去', '公司', '怎么', '做', '公交'],
#  ['随机', '播放', '一首', '的', '歌曲'],
#  ['小', '和尚', '第', '4', '集', '往后', '接着', '播放', '我要', '看', '呢'],
#  ['怎么', '到', '人民', '南路', '十号', '啊'],
#  ['早上', '八点', '就', '可以', '把', '智能', '窗帘', '了'],
#  ['冰箱', '冷冻室', '温度', '调', '成', '零下', '17', '度', '好不好', '呢'],
#  ['睡觉', '之前', '我要', '看', '2006', '年', '英国', '喜剧电影'],
#  ['我', '想', '继续', '看', '一个', '盗墓', '我', '找个', '类似', '于', '怒', '晴', '湘西', '的'],
#  ['告诉', '我', '明天', '三亚', '的', '空气质量', '好', '吗'],
#  ['帮', '我', '开启', '一下', '周四', '上午', '10', '点', '参加', '讲座', '的', '行程', '。'],
#  ['明早', '十点', '的', '时候', '，', '请', '不要', '忘', '了', '提醒', '我', '抢票'],
#  ['我', '现在', '就要', '看', '赵露', '思演', '的', '古装剧', '的', '第', '30', '集'],
#  ['历史', '类', '的', '电影', '随机', '来', '一个', '90', '年代', '的', '吧'],
#  ['找', '出来', '韩庚', '跳舞', '的', '视频'],
#  ['播放', '王子', '主持', '的', 'FM98', '点', '5'],
#  ['1', '月', '6', '日', '播放', '的', '新冠', '疫苗', '还', '能', '找到', '视频', '吗'],
#  ['回放', '今天下午', '5', '点', '开始', '的', '女子单打', '网球', '比赛', '视频'],
#  ['今天', '有', '什么', '重大', '的', '国际', '新闻', '没有', '，', '放', '来看', '一下'],
#  ['立刻', '播放', '的'],
#  ['赶快', '查查', '规划', '一下', '回家', '红绿灯', '最少', '的', '路线'],
#  ['查询', '空气', '净化器', '还', '剩下', '多少'],
#  ['10', '月', '3', '号', '拉萨', '的', '空气质量', '怎么样'],
#  ['查下', '广州', '飞', '上海', '的', '机票', '还有', '吗'],
#  ['说', '说', '今天', '有', '长春', '去', '武汉', '的', '火车', '吗'],
#  ['18', '年', '在', '中国', '大陆', '播出', '的', '动漫', '非人', '哉', '给', '我', '播放', '一下'],
#  ['李一桐', '出演', '的', '电视剧', '来', '一个', '吧'],
#  ['查查', '一下', '从', '芜湖', '到', '的', '路线'],
#  ['播', '一个', '晚上', '20', '点', '更新', '的', '国产', '动漫'],
#  ['我', '想', '看', '2021', '年', '4', '比', '3', '韩国', '的', '比赛', '视频'],
#  ['找到', 'FM102', '点', '6', '的', '四川', '电台'],
#  ['可不可以', '打开', '空气', '净化器', '呀'],
#  ['准备', '做', '烤肉', '，', '把', '蒸', '烤箱', '切换', '到', '热风', '烧烤', '模式', '吧'],
#  ['调到', 'FM106', '点', '1', '的', '四川', '新闻广播', '找个'],
#  ['让', '洗衣机', '空气', '洗', '试试', '可以', '不'],
#  ['帮忙', '记', '一下', '2', '月', '1', '号', '看', '春晚'],
#  ['按', '时间', '顺序', '播放', '陕西', '交通广播', '的', '节目'],
#  ['我', '想', '知道', '昆明', '明天', '早上', '会', '不会', '下', '小雨', '。'],
#  ['最近', '一周', '大', '理会', '有', '大风', '出现', '吗'],
#  ['来', '一首', '2009', '年', '王力宏', '的', '曲子', '吧'],
#  ['查询', '海南', '最高', '温度', '多少'],
#  ['哈尔滨', '今天', '晚上', '有', '小雪', '吗'],
#  ['放', '一下', '一人之下', '第', '3', '季', '相关', '视频'],
#  ['播放', '不', '完美', '的', '她'],
#  ['把', '悲伤', '自己', '单曲', '循环', '播放'],
#  ['下', '周末', '去', '兰州', '穿', '什么', '合适', '啊'],
#  ['问问', '九江', '飞', '重庆', '的', '飞机', '起飞', '了', '吗'],
#  ['新闻台', '的', '重庆', '之声', '帮', '我', '找', '一', '找'],
#  ['帮', '我', '找', '蔡', '徐坤', '的', '情人'],
#  ['看看', '张楠', '主持', '的', '音乐', '之声'],
#  ['电台节目', '放', '一个', '主持', '的'],
#  ['赶快', '的', '查询', '开', '过来', '的', '客车', '是', '几点', '呢'],
#  ['我', '想', '看', '泰国', '的', '偶像剧', '呢', '青春', '一点', '的'],
#  ['给', '我', '放', '一个', '篮球', '明星', '的', 'NBA', '视频'],
#  ['农历', '9', '月', '初八', '提醒', '我', '一下', '我', '妈妈', '要'],
#  ['播', '一下', '第二', '这张', '专辑', '里', '的', '循环', '放'],
#  ['给', '我', '听', 'Bieber', '的'],
#  ['接着', '上次', '的', '好', '都', '靠', '训练', '而', '来'],
#  ['马上', '给', '我', '放', '一个', '的', '路况', '信息'],
#  ['可以', '继续', '收听', '一下', '主持', '的', '今日', '路况', '速报', '吗'],
#  ['90', '年代', '美国', '的', '科幻片', '儿有', '吗', '，', '看', '一个'],
#  ['请', '给', '我', '看看', '到', '三', '医院', '怎么', '走快'],
#  ['即刻', '收听', 'FM102.5', '的', '体育', '广播'],
#  ['帮', '我查', '一下', '后天', '是', '农历', '几月', '几日'],
#  ['后天', '是不是', '清明节', '呢'],
#  ['好', '用', '分享'],
#  ['创建', '周日', '下午', '2', '点去', '医院', '复查', '的', '日程'],
#  ['开门', '节是', '几月', '几号'],
#  ['找到', '8', '点到', '9', '点', '的', '音乐', '圈'],
#  ['立刻', '告诉', '我', '北京', '开往', '广州', '的', '复兴号', '开车', '了', '没'],
#  ['来', '毛', '不易', '像', '我', '这样', '的', '人'],
#  ['回答', '我', '想', '知道', '今天', '是', '礼拜', '几呀'],
#  ['偶像剧', '幸福', '触手可及', '最后', '一集', '播放', '一下'],
#  ['明天', '空气', '指数', '怎么样'],
#  ['你', '可以', '帮', '我', '播放', '一下', '啊', '吧'],
#  ['我要', '听', '周深', '和', '王子', '一起', '唱', '的'],
#  ['今天下午', '16', ':', '59', '定个', '闹钟'],
#  ['日本', '歌手', '的', '日语', '歌', '随机', '来', '一首', '呗'],
#  ['我', '想', '看', '一个', '有点', '剧情', '的', '韩国', '偶像剧'],
#  ['到', '贵阳', '的', '开车', '路线'],
#  ['浙江', '今天', '有没有', '台风', '登陆'],
#  ['周二', '上午', '9', '点', '45', '去', '医院', '打', '疫苗', '的', '提醒', '制定', '一下', '。'],
#  ['现在', '问', '你', '一', '下来', '一张', '最快', '飞', '包头', '的', '机票'],
#  ['帮', '我', '播放'],
#  ['我', '想', '知道', '中国', '的', '阴历', '4', '月', '15', '是', '哪一天', '呢'],
#  ['2007', '年', '王力宏', '的', '我们', '的', '歌', '播放', '一下', '吧'],
#  ['下', '周三', '晚上', '需要', '多加', '衣物', '吗', '？'],
#  ['明天', '提醒', '我', '去', '接机'],
#  ['查查', '然后', '告诉', '我', '自驾车', '去', '大理', '的', '路线'],
#  ['想', '听', '古筝', '了', '，', '来', '一首', '吟', '听听'],
#  ['我', '今天', '想', '去', '公园', '玩', '，', '会', '不会', '冷', '啊'],
#  ['今年', '的', '忏悔', '节是', '周几'],
#  ['的', '歌曲', '现在', '随机', '来', '一首', '呢'],
#  ['扫地', '机器人', '不要', '扫地', '了'],
#  ['到', '湖南', '常德', '怎么', '走', '才', '到'],
#  ['北京', '到', '上海', '的', '机票', '9', '月', '9', '号', '的'],
#  ['哈尔滨', '最近', '穿衣', '指数', '怎么样'],
#  ['把', '主持', '的', '电台', '里', '阅读', '时光', '节目', '打开'],
#  ['今年', '的', '几月', '几号', '是', '摩洛哥', '新娘', '节'],
#  ['我要', '看', '一会', '战争片', '我', '是', '特种兵'],
#  ['你', '可以', '播放', '一下', '凤凰', '传奇', '的', '快乐', '的', '音乐', '吗'],
#  ['把', '洗衣机', '调', '为', '烘干', '模式', '。'],
#  ['把', '空调', '调', '成', '最高', '的', '温度'],
#  ['给', '我', '打开', '车库', '自动门'],
#  ['播放', '的', '专辑', '风云', '2', '里面', '的', '歌曲'],
#  ['武汉', '明天', '紫外线', '指数', '怎么样'],
#  ['周六', '晚上', '7', '点去', '贵阳', '的', '高铁', '票', '价格', '。'],
#  ['2021', '年', '的', '小黄瓜', '电台', '播放', '一下'],
#  ['空调', '风速', '调', '到', '最高'],
#  ['今天', '有没有', '啥', '好看', '的', '明星', '，', '放', '来', '看看'],
#  ['帮', '我定', '一个', '周六', '上午', '8', '点去', '图书馆', '的', '闹钟', '。'],
#  ['有', '的', '恭喜', '恭喜', '就', '放', '一下'],
#  ['请', '帮', '我', '近期', '河北', '气温', '总', '指数'],
#  ['我',
#   '想',
#   '听',
#   '一个',
#   '频率',
#   '是',
#   '九九',
#   '点八',
#   '的',
#   '广州',
#   '电台',
#   '风云',
#   '962',
#   '呢'],
#  ['11', '月', '11', '日', '从', '北京', '去', '东京', '的', '航班', '在', '什么', '时候', '。'],
#  ['创建', '25', '号', '去', '上海', '参加', '婚礼', '的', '日程'],
#  ['寻找', '李荣浩', '早期', '唱歌', '视频'],
#  ['我', '让', '你', '打开', '一下', '客厅', '的', '灯', '带'],
#  ['收听', '频率', '是', '八七', '点', '六', '的', '开心', '茶馆'],
#  ['随机', '播放', '韩红', '的', '歌'],
#  ['给', '我', '收听', '一个', '频率', '是', '一零', '五点', '三', '的', '襄樊', '文艺', '台'],
#  ['你', '可以', '在', '2', '月', '10', '号', '提醒', '我', '给', '哥哥', '吗', '？'],
#  ['放', '一下', '钟汉良', '最新', '电视剧', '的', '幕后', '花絮', '吧'],
#  ['宫', '我', '想', '看', '是', '古装剧'],
#  ['过', '两天', '的', '温度', '怎么样', '有没有', '小雨'],
#  ['单曲', '循环', '一个', '钢琴曲', '可以', '吗'],
#  ['帮', '我', '拨', '一下张', '楠', '主持', '的', '1039', '新闻', '早报'],
#  ['我', '一会儿', '准备', '就要', '听', '中央广播电台', '的', '新闻联播'],
#  ['2021', '年', '在', '中国', '播出', '的', '甜', 'cut', '视频', '帮', '我', '播放', '吧'],
#  ['播放', '王玲', '主持', '的', '音乐'],
#  ['天太热', '了', '，', '帮', '我', '把', '空调', '温度', '调低', '三度', '吧', '。'],
#  ['不要', '把', '5', '月', '20', '号', '上午', '的', '备忘录', '全部', '删除'],
#  ['看', '5', '月', '12', '日', '的', '纪录片', '传奇', '故事'],
#  ['帮', '我', '把', '空气', '净化器', '调', '成', '静音', '模式'],
#  ['将', '7', '月', '12', '号', '的', '备忘录', '修改', '到', '4', '月', '27', '号', '提醒'],
#  ['我', '需要', '你', '让', '我', '知道', '17', '点有', '始发', '的', '大客车', '不'],
#  ['查询', '1', '月', '江西', '是', '多', '降雨', '吗'],
#  ['帮', '我', '找', '下', '美国', '的', '和', '的', '第一集'],
#  ['全屋', '杀菌', '模式', '关闭'],
#  ['把', '空调', '的', '制热', '模式', '开启'],
#  ['下雪', '了', '好', '冷', '呀', '，', '帮', '我', '打开', '取暖器', '吧'],
#  ['恋爱', '题材', '的', '有声', '小说', '随便', '播', '一个', '吧'],
#  ['我', '想', '确定', '一下', '后天', '的', '紫外线', '指数'],
#  ['老', '歌手', '的', '歌来', '几首', '吧'],
#  ['给', '我', '唱', '一个', '开心', '的', '阿拉伯语', '歌曲', '呢'],
#  ['我', '非常', '需要', '知道', '星期日', '是', '哪天', '啊'],
#  ['贵阳', '那边', '天气', '怎么样'],
#  ['搜索', '3', '月', '5', '日', '是', '星期', '几'],
#  ['我', '想', '你', '给', '我', '主持', '的', '音乐', '之声'],
#  ['特别', '搞笑', '的', '那个', '男', '放给'],
#  ['播放', ' ', '，', 'Bieber', '唱', '的', '啊'],
#  ['在', '周五', '早上', '提醒', '我', '学习', '英语'],
#  ['帮', '我', '关闭', '6', '月', '10', '号', '至', '7', '月', '10', '的', '备忘录'],
#  ['我', '想', '听任', '的'],
#  ['给', '空调', '风速', '调大些'],
#  ['空调', '冷气', '风速', '调至', '13'],
#  ['给', '我', '放', '一下', '国外', '新闻', '再次', '的', '视频'],
#  ['我要', '去', '查', '一下', '5', '号', '的', '火车票'],
#  ['查', '一下', '电磁炉'],
#  ['找', '一下', '到', '重庆', '荣昌', '区', '的', '路'],
#  ['请', '将', '电扇', '调到', '3', '档好', '么'],
#  ['你', '不用', '在', '明天', '11', '点', '的', '时候', '叫', '我', '去', '吃', '自助餐'],
#  ['给', '我', '把', '音响', '关', '了', '。'],
#  ['我', '想', '知道', '去', '昆明', '旅游', '经济舱', '价格'],
#  ['今年', '的', '三月', '节是', '什么', '时候'],
#  ['赶快', '查一查', '几月', '几号', '是', '春节', '呢'],
#  ['七夕', '是', '周几'],
#  ['13', ':', '20', '起床', '去', '游泳'],
#  ['能',
#   '不能',
#   '帮',
#   '我',
#   '将',
#   '5',
#   '月',
#   '1',
#   '号',
#   '的',
#   '备忘录',
#   '修改',
#   '成',
#   '4',
#   '月',
#   '29',
#   '号'],
#  ['不要', '忘', '了', '提醒', '我', '拿', '在', '明天', '早上', '8', ':', '40', '的', '时候'],
#  ['把', '厨房', '灯', '的', '色温', '调', '到', '白光', '吧'],
#  ['请调', '到', '的', '湖南', '交通', '广播电台'],
#  ['看', '一部', '2020', '年', '韩国', '最火', '的', '爱情', '剧'],
#  ['播放', '任素', '汐', '主演', '的', '驴', '得', '水'],
#  ['拨到', 'FM97', '爱家', '频道', '听', '到底'],
#  ['随机', '播放', '一首', '里', '的', '歌曲'],
#  ['明天', '海淀', '是', '下雨', '吗'],
#  ['30', '分钟', '后', '关闭', '饮水机'],
#  ['韩语', '歌', '随机', '来', '一首', '吧'],
#  ['俄语', '歌', '有没有', '比较', '治愈', '的', '放', '一个'],
#  ['是不是', '能', '把', '连续剧', '继续', '播', '一下', '呢'],
#  ['调', '到', '蓝天', 'I', '的', '畅通'],
#  ['野史', '下酒', '就', '恶霸', '波', '那个', '播出', '一下'],
#  ['美国', '的', '剧情片', '可以', '来', '一个', '给', '我', '看', '吗'],
#  ['播放', '麻辣', '这个', '动漫', '的', '版'],
#  ['我', '现在', '就', '想', '听', '一下', '郎朗', '的', '钢琴曲', '呢'],
#  ['收听', '江苏', '的', '联通新', '势力', '男生宿舍'],
#  ['美国',
#   '纪录片',
#   '迈克尔',
#   '杰克逊',
#   '就是',
#   '这样',
#   '在',
#   '2009',
#   '年',
#   '上映',
#   '的',
#   '我',
#   '想',
#   '看看'],
#  ['前年', '的', '国庆节', '是', '什么', '时候'],
#  ['农历', '的', '麦尔节', '是', '哪天'],
#  ['农历', '的', '立夏是', '哪天'],
#  ['帮', '我', '查询', '周日', '宁波', '会', '下雨', '吗'],
#  ['后天', '南京', '的', '温度', '是', '多少', '摄氏度'],
#  ['看', '下', '中心', '走', '那条', '路快'],
#  ['不要', '帮', '我', '关闭', '明天', '9', '点', '的', '闹钟'],
#  ['可以', '让', '洗衣机', '进入', '洗', '模式', '吗', '，', '赶时间', '呀'],
#  ['我', '想要', '了解', '农历', '12', '月', '17', '是', '礼拜', '几'],
#  ['差', '一下', '到', '重庆', '荣昌', '区', '的', '路'],
#  ['嘉兴', '15', '号', '到', '扬州', '的', '汽车票', '还有', '吗'],
#  ['不要', '将', '今天', '晚上', '5', '点', '的', '闹钟', '删除'],
#  ['我要', '起床', '，', '帮', '我', '把', '灯', '切换', '到', '模式', '吧'],
#  ['给', '我', '看', '下', '2020', '年', '青岛', '的', '降水', '情况'],
#  ['能',
#   '不能',
#   '听',
#   '一下',
#   '继续',
#   '张国荣',
#   '这张',
#   '专辑',
#   '里',
#   '的',
#   '歌曲',
#   '，',
#   '随机',
#   '来',
#   '一首',
#   '就行'],
#  ['告诉', '我', '祖鲁', '节是', '几月', '几号'],
#  ['农历', '的', '什么', '时候', '是', '建军节'],
#  ['给', '他', '报', '一下', '农历', '的', '几月', '几号', '是', '乞巧', '节', '啊'],
#  ['前天', '上海', '刮风', '了', '吗'],
#  ['来', '一首', '90', '年代', '的', '英文歌', '呗'],
#  ['今年', '什么', '时候', '是', '虫', '王节'],
#  ['我', '想', '看', '周杰伦', '唱', '的', '视频'],
#  ['查看', '重庆', '湿度', '报告'],
#  ['来', '继续', '收听', '频率', '是', '九', '零点', '零', '的', '电台'],
#  ['我要', '听', '的', '故事'],
#  ['能',
#   '不能',
#   '马上',
#   '帮',
#   '我',
#   '将',
#   '5',
#   '月',
#   '8',
#   '号',
#   '的',
#   '提醒',
#   '修改',
#   '成',
#   '4',
#   '月',
#   '29',
#   '号'],
#  ['快点', '看看', '郑州', '到', '驻马店', '的', '大客', '到', '站', '了', '没有', '呢'],
#  ['播放', '笙', '演奏', '的'],
#  ['我', '想', '看看', '这个', '月', '15', '号', '是', '星期', '几'],
#  ['查下', '日历', '大前天', '是', '什么', '节日', '啊'],
#  ['我要', '看', '经典', '的', '动漫', '舒克', '和', '贝塔'],
#  ['回放', '一下', '昨天', '的', '篮球', '快报'],
#  ['帮', '我', '把', '调至', '30', '度'],
#  ['周日', '傍晚', '台风', '有', '几级'],
#  ['周杰伦', '的', '叶惠美', '可以', '顺序', '播放', '吗'],
#  ['播放', '王者', '荣耀', '游戏', '直播'],
#  ['江西', '的', '空气质量', '稳定', '吗'],
#  ['播放', '林依晨', '的', '流行歌'],
#  ['频率', '是', '九', '三点', '二', '的', '荆州', '电台', '新闻频道', '可以', '收听', '一下', '吗'],
#  ['呼吸', '之野', '里面', '的', '单曲', '循环', '一下', '吧'],
#  ['两个', '月', '后', '去', '广州', '开会', '，', '提醒', '我', '哦'],
#  ['帮', '我', '找到', '菏泽', '的', '路线'],
#  ['十分钟', '后', '打开', '客厅', '空调', '可以', '吗'],
#  ['把', '后天', '下午', '两点钟', '跟', '朋友', '谈', '生意', '的', '闹钟', '设定', '好', '。'],
#  ['放', '音乐', '类', '的', '襄樊', '交通', '音乐台'],
#  ['按', '顺序', '播放', '的', '相关', '视频'],
#  ['明天', '的', '风向', '是', '什么'],
#  ['我要', '去', '汕尾', '告诉', '我', '穿', '什么', '穿多厚', '合适'],
#  ['和', '李一桐', '演', '的', '剑', '王朝', '给', '我', '放下'],
#  ['这周', '我', '要', '坐火车', '回', '北京', '，', '现在', '有票', '没'],
#  ['我', '想', '你', '给', '我', '播放', '胡彦斌', '的', '专辑', '太歌', '里', '的', '歌', '呢'],
#  ['我', '要查', '5', '月', '29', '去', '上海', '的', '经济舱', '。'],
#  ['能', '找', '一个', '范', '迪塞尔', '导演', '的', '美剧', '看看', '么'],
#  ['请', '不要', '在', '5', '点', '通知', '我', '上网'],
#  ['鞍山', '后天', '会', '不会', '下雨', '啊'],
#  ['西单', '到', '天坛公园', '不行', '如何', '走', '才', '合适', '呢'],
#  ['给', '我', '找', '一下', '2018', '对', '的', '羽毛球', '大赛', '的', '视频'],
#  ['2014', '年', '周星驰', '导演', '上线', '的', '电影', '播放', '一个', '呢'],
#  ['陇', '端节', '是', '星期', '几'],
#  ['父亲节', '是', '几号', '？'],
#  ['播放', '2018', '年', '以后', '的', '言情剧', '看看'],
#  ['开启', '洗衣机', '的', '模式', '可以', '吗'],
#  ['河南', '交通广播', '里', '的', '世界', '的', '快', '搜索', '一下'],
#  ['唱', '一首', '英文', '流行歌曲', '呢'],
#  ['帮', '我', '找', '快', '把', '我哥', '带走', '的', '第', '23', '集'],
#  ['我', '想', '看', '动漫', '，', '给', '我', '播放', '一个', '羊羊', '运动会', '精彩', '解说', '吧'],
#  ['立即', '播放', '情感', '节目', '解忧', '电台'],
#  ['能', '不能', '来', '一个', '音乐', '电台节目', '给', '我', '呢'],
#  ['今年', '端午节', '是', '周几'],
#  ['百分之', '的', '这个', '游戏', '解说', '视频', '帮', '我', '找', '找'],
#  ['厦门', '开往', '北京', '的', '高铁', '今天', '有票', '吗'],
#  ['关门', '节是', '星期', '几'],
#  ['帮', '我', '记', '一下', '4', '月', '30', '号', '提醒', '我', '去', '开发票'],
#  ['播放', '安徽', '广播电台', '主持', '的', '幸福', '不', '晚点'],
#  ['不',
#   '知道',
#   '还',
#   '能',
#   '不能',
#   '找到',
#   '四川',
#   '一',
#   '女子',
#   '床头',
#   '发现',
#   '的',
#   '新闻',
#   '视频'],
#  ['播放', '末代皇帝', '这部', '传记类', '的', '电影', '。'],
#  ['杨幂', '去年', '的', '剧能', '播放', '一个', '吗'],
#  ['听个', '刘晓', '的', '节目', '就', '听', '吧'],
#  ['布衣', '天子', '的', '第三集', '继续', '播放', '吧'],
#  ['查询', '播放', '周三', '哈尔滨', '是', '晴天', '吗'],
#  ['恐怖', '小说', '接着', '放', '这部', '的'],
#  ['请', '播放', '当', '幸福', '来', '敲门', '这部', '传记类', '电影', '。'],
#  ['王菲', '和', '陈奕迅', '的', '合唱', '歌曲', '传奇', '播放', '一下'],
#  ['麻烦', '找到', '陕西', '戏曲', '广播', '按', '时间', '顺序', '播放', '里面', '的', '花鼓戏', '节目'],
#  ['频率', '是', '九', '八点', '一', '的', '移动', '电视', '收听', '一下', '吧'],
#  ['给', '我', '把', '凤凰', '传奇', '的', '歌', '顺序', '播放', '吧'],
#  ['今天', '有', '关于', '韩国', '的', '新闻', '么', '，', '放', '来', '看看'],
#  ['接着', '放', '第', '3', '集', '葫芦', '是', '动漫', '啊', '别', '了'],
#  ['最近', '比较', '火', '的', '单曲', '循环', '吧'],
#  ['10', '月', '1', '日', '是', '什么', '节日'],
#  ['找到', '播放'],
#  ['查询', '下周', '沧州', '气温', '会', '偏', '高', '吗'],
#  ['播放', '一下', '国创', '动漫', '斗罗', '大陆'],
#  ['请', '随机', '播放', '一首', '钢琴曲', '。'],
#  ['马上', '给', '放', '3', '点钟', '就', '开始', '播', '的', '吃', '鸡', '游戏', '的', '直播'],
#  ['我要', '去', '洛阳', '看看', '怎么', '走'],
#  ['郭敬明', '的', '小', '时代', '幕后', '花絮', '放', '一下'],
#  ['帮', '我', '设置', '周六', '下午', '1', '点去', '进货', '的', '闹钟', '。'],
#  ['快', '看看', '星期二', '是', '几号', '啊'],
#  ['外边', '几度', '啊', '冷不冷'],
#  ['看', '国产', '动漫', '斗罗', '大陆'],
#  ['给', '我', '放', '一下', '90', '年代', '美国', '电影', '的'],
#  ['你', '能', '帮', '我播', '一下', '和', '王', '之', '导演', '的', '这个', '世界', '脸', '吗'],
#  ['9', '点', '叫', '我', '起床'],
#  ['有没有', '什么', '听', '了', '就', '想', '笑', '的', '的', '德语', '歌'],
#  ['我', '想要', '听', '广州', '音乐', '之声', '给', '我', '调到', '102', '点', '7', '去'],
#  ['我弟', '周六', '上午', '要开', '家长会', '，', '闹钟', '一定', '要', '提醒'],
#  ['我', '想', '看', '前面', '看', '的', '清宫', '的', '第三集'],
#  ['怎么', '去', '安庆', '城', '啊', '还有', '汽车票', '吗'],
#  ['我', '想', '收', '一下', '天津', '广播', '的', '音乐', '不', '这个', '广播'],
#  ['电视', '声音', '再', '调大点', '行不行', '呢'],
#  ['我', '想', '再', '一遍', '周三', '凌晨', '一点', '播放', '的', '英雄'],
#  ['立刻', '告诉', '我', '12', '月', '12', '日', '是', '星期四', '还是', '星期五'],
#  ['可不可以', '帮', '我', '把', '加湿器', '调到', '1', '档', '呢'],
#  ['青年节', '是', '什么', '时候'],
#  ['有没有', '新', '的', '适合', '表白', '氛围', '的', '歌曲', '播放', '一下', '啊'],
#  ['是否', '可以', '将', '9', '月', '9', '号', '去', '广东', '的', '这个', '提醒', '取消', '了'],
#  ['陈鸿宇', '的', '步履', '不停', '里面', '的', '歌曲', '随机', '来', '一首', '呢'],
#  ['我要', '听', '一会儿', '的', 'I', '的', '星空', '秀', '在', 'FM95', '点', '5'],
#  ['到', '喀什', '多久', '啊'],
#  ['现在', '放', '一下', '的', '电台节目', '记忆'],
#  ['我', '想要', '一首', '很', '治愈', '的', '德语', '歌听'],
#  ['频率', '是', '九九', '点', '六', '的', '中央人民广播电台', '节目', '给', '我', '收听', '一下', '吧'],
#  ['我', '需要', '知道', '后天', '到底', '是', '几月', '几日'],
#  ['9', '点', '23', '到', '济南', '西', '的', '高铁', '票', '还有', '吧'],
#  ['想要', '风扇', '一直', '对', '着', '我', '吹', '，', '帮', '我', '让', '风扇', '停止'],
#  ['你', '可以', '找', '一下', '2020', '年', '最', '人气', '的', '歌曲', '给', '我', '播放', '吗'],
#  ['查询', '并', '把', '去', '酒店', '红绿灯', '最少', '的', '路线', '告诉', '告诉', '我'],
#  ['帮', '我', '设置', '一个', '8', '号', '上午', '9', '点', '的', '闹钟', '。'],
#  ['设置', '一个', '8', '号', '下午', '2', '点去', '驾校', '的', '闹钟', '。'],
#  ['这', '周', '平均', '降雨量', '多少'],
#  ['你', '看', '能', '不能', '在', '两点', '的', '时候', '提醒', '周'],
#  ['来', '一首', '钢琴', '弹唱', '的', '勇气'],
#  ['快点', '查查', '青年节', '是', '几号'],
#  ['我', '已经', '休息', '好', '了', '，', '按摩器', '暂停', '使用', '。'],
#  ['FM104', '点', '3', '走进', '帮', '我', '放', '一下'],
#  ['明年', '节是', '周几'],
#  ['随机', '来', '一首', '张国荣', '的', '歌曲', '可以', '吗'],
#  ['能', '不能', '5', '点', '的', '时候', '提醒', '我', '喝', '中药'],
#  ['天池', '景区', '今天', '平均温度', '多少'],
#  ['放', '一个', '频率', '是', '九', '七点', '五', '的', '江苏', '文艺', '广播电台'],
#  ['2', '月', '13', '号', '是', '周几'],
#  ['我', '现在', '就要', '看', '美国', '演员', '安妮', '海瑟薇', '的', '剧', '呢'],
#  ['隔壁', '老樊', '的', '我', '曾', '放到', '按照', '顺序', '播放'],
#  ['播放', '林依晨', '和', '张', '参演', '的', '小女', '花不弃'],
#  ['从', '第一集', '开始', '播放', '如懿传', '吧'],
#  ['请', '你', '增加', '一个', '11', '月', '13', '号', '的', '备忘录'],
#  ['继续', '播放', '来', '那个', '言情剧', '吧'],
#  ['毒液', '2', '继续', '给', '我', '播放', '可以', '吗'],
#  ['今年', '的', '上', '节', '是', '哪天'],
#  ['循环', '收听', '的', '爱', '上', '男声', 'FM'],
#  ['九点', '十堰', '发车', '去', '孝感', '的', '火车票', '还有', '吗'],
#  ['查询', '一下', '然后', '告诉', '我', '去', '学校', '的', '最快', '路线'],
#  ['问', '你', '今天', '是', '哪个', '节假日'],
#  ['帮', '我', '把', '洗衣机', '的', '快', '洗', '模式', '打开', '。'],
#  ['下周', '就要', '歌唱', '比赛', '了', '，', '我要', '单曲', '循环', '给', '听', '。'],
#  ['能', '帮', '我', '看', '下去', '青海', '旅游', '的', '往返', '规划', '吗'],
#  ['打开', '现在', '正在', '播放', '的', '熊出没', '之', '探险', '日记', '2'],
#  ['圣帕特里克', '节是', '今年', '的', '什么', '时候'],
#  ['给', '我', '转到', '中央人民广播电台', '的', '音乐', '之声'],
#  ['给', '我', '搜索', '一下', '去年', '世界', '女子', '体操比赛', '的', '精彩', '片段', '视频'],
#  ['嘉兴', '明天', '会', '不会', '有', '大雨'],
#  ['刺杀', '小说家', '吗', '，', '好像', '是', '奇幻', '电影'],
#  ['纪录片', '下', '帮', '我', '查询', '一下'],
#  ['我', '想', '看', '2020', '年谍', '战', '电视剧', '新世界', '的', '花絮'],
#  ['请', '提醒', '我', '明天', '上午', '十点', '把', '拿', '回来'],
#  ['找', '一下', '每周五', '，', '10', '点', '更新', '的', '国产', '动漫'],
#  ['你', '能', '继续', '给', '我', '播放', '西游记', '这个', '电视剧', '吗'],
#  ['找', '一下', '步行', '到', '最近', '的', '的', '路'],
#  ['我',
#   '命令',
#   '你',
#   '给',
#   '我',
#   '设置',
#   '一个',
#   '明天',
#   '上午',
#   '8',
#   '点',
#   '上课',
#   '的',
#   '闹钟',
#   '。'],
# ...
#  ['小宝', '的', '小品', '特别', '惊喜', '来', '听'],
#  ['下', '周六', '是', '多少', '号'],
#  ['但是', '如果', '医生', '的', '这', '就是', '一起', '服务'],
#  ['农历', '的', '八月', '初五', '和', '农历', '八月', '初六', '哪天', '是', '星期一', '呢'],
#  ['当', '我', '听到', '这', '首歌', '的', '时候', '她', '在', '我', '心里', '还是', '的', '样子'],
#  ['你', '自己', '我', '去', '故宫'],
#  ['今年', '的', '是', '星期', '几'],
#  ['给', '我', '放', '小说', '的', '俄语', '版'],
#  ['帮', '我', '把', '空调', '温度', '调到', '19', '度'],
#  ['播放', '九二', '点', '四', '的', '人民', '广播电台'],
#  ['今早', '的', '快乐', '生活', '一点', '通', '晚上', '还有', '重播', '吗', '帮', '我', '看', '下'],
#  ['有', '一', '女友', '人', '到场', '跟', '不停'],
#  ['你', '可以', '在', '4', '月', '25', '号叫', '我', '吗'],
#  ['哪个', '节日', '是', '农历', '的', '五月', '初五', '啊'],
#  ['请', '帮', '我', '播放', '上海', '戏剧', '曲艺', '广播', '的', '所有', '昆曲', '类节目'],
#  ['今年', '建党', '节是', '周几'],
#  ['赶紧',
#   '替',
#   '我',
#   '看看',
#   '农历',
#   '的',
#   '七月',
#   '初五',
#   '和',
#   '农历',
#   '七月',
#   '初六',
#   '哪天',
#   '是',
#   '星期四',
#   '呢'],
#  ['来', '一首', '粤语', '的', '小城', '大事'],
#  ['怎么样', '才能', '从', '西单', '到', '如何', '走', '不', '绕路'],
#  ['播放', '佟', '大为', '和', '刘诗', '的', '如果', '可以', '这样', '爱'],
#  ['现在', '帮', '我建', '一个', '备忘录', '7', '小时', '50', '分钟', '提醒', '我'],
#  ['唐嫣', '2020', '年', '播放', '的', '剧', '给', '我', '找', '一个', '播放'],
#  ['可是', '其', '唱片', '公司', '却', '表示', '到', '仍', '不能', '个', '唱', '的', '压力'],
#  ['固原', '没有', '平均', '几度'],
#  ['明天', '早上', '七点', '打开', '热水器'],
#  ['首都', '晚间', '报道', '是', '在', '北京', '新闻', '播放', '还是', '中央', '播放'],
#  ['帮', '我', '把', '新闻', '类', '电台', '990', '新闻', '频率', '播放', '可以', '吗'],
#  ['许嵩', '在', '2011', '年', '发行', '的', '歌来', '一首', '呗'],
#  ['帮', '我', '重播', '昨天', '的', '体育', '的', '说唱', 'CBA'],
#  ['播', '一下', '英文版', '的', '登'],
#  ['内蒙古', '通知', '今天', '会', '出现', '沙尘暴'],
#  ['快给我', '播', '小说', '海明威', '的', '老人与海'],
#  ['能', '不能', '播放', '一个', '2016', '年', '奥运会', '的', '视频'],
#  ['祝', '所有', '的', '老师'],
#  ['给', '我', '一个', '荣耀', '发财', '快报', '系列', '完整版', '游戏', '解说', '视频', '吧'],
#  ['七月', '第二周', '韩娱', '每周', '一星', '韩国', '弟弟', '李胜基', '灿烂', '成长', '图'],
#  ['给', '我', '来', '许嵩', '的', '乌鸦', '吧'],
#  ['帮', '我', '打开', '体育', '正在', '播放', '的', '运动', '有', '态度', '吧'],
#  ['现在', '请', '给', '我', '循环', '播放', '十二生肖', '的', '故事', '英文版'],
#  ['把', '空调', '打开', '。'],
#  ['给', '查查', '郑州', '去往', '沈阳', '的', '动车', '哪天', '有票', '啊'],
#  ['马上', '就', '能', '听', '浙江', '人民', '广播电台', '的', '新闻', '快报', '了'],
#  ['可以',
#   '帮',
#   '我',
#   '转到',
#   '广西',
#   '粽子',
#   '旅游',
#   '的',
#   '法治',
#   '最',
#   '前线',
#   '吗',
#   '我',
#   '想',
#   '看',
#   '下'],
#  ['续播', '一下', '90', '年代', '的', '那个', '战争片'],
#  ['有人', '第一次', '见', '她', '美', '得', '充满', '和'],
#  ['随便', '给', '找', '一个', '连载', '的', '国漫', '看'],
#  ['收听', '频率', '是', '八七', '点', '六', '的', '小说', '连播'],
#  ['就是', '五河', '人民', '广播电台', '给', '我', '拨', '93', '点', '3'],
#  ['现在', '我要', '知道', '还有', '去', '四川', '哪里', '的', '大巴车', '票'],
#  ['打开', '客厅', '的', '空调', '制热', '我', '想'],
#  ['麻烦', '帮', '我', '创建', '周一', '下午', '4', '点去', '买', '书', '的', '闹钟', '。'],
#  ['现在', '去', '空调', '怎么', '走', '啊'],
#  ['我',
#   '想',
#   '知道',
#   '国庆节',
#   '下午',
#   '3',
#   ':',
#   '00',
#   '左右',
#   '从',
#   '长春',
#   '开往',
#   '沈阳',
#   '的',
#   '特快',
#   '列车',
#   '还有',
#   '吗'],
#  ['我', '可以', '随机', '听', '一首', '日语', '歌', '吗'],
#  ['把', '打开', '。'],
#  ['找个', '电台', '听', '就', '有', '车', '有', '得', '吧', '羊城', '交通'],
#  ['给', '我', '查查', '阴历', '1', '月', '12', '是', '阳历', '几号'],
#  ['将',
#   '后天',
#   '上午',
#   '8',
#   '点多',
#   '去',
#   '拼',
#   '多多',
#   '给',
#   '水果',
#   '的',
#   '闹钟',
#   '设置',
#   '一下',
#   '。'],
#  ['删除', '我', '所有', '闹钟', '，', '包括', '下午', '9', '点', '的', '那个'],
#  ['继续', '播', '一下', '恐怖', '小说', '死亡', '第三章'],
#  ['黄景', '犯罪', '类型', '的', '电视剧', '来', '一个', '播放', '呢'],
#  ['冰箱', '牛奶', '还有', '呢', '，', '告诉', '我下', '吧'],
#  ['因为',
#   '和',
#   '我',
#   '的',
#   '性格',
#   '很',
#   '生活',
#   '中',
#   '的',
#   '我',
#   '有时候',
#   '比',
#   '她',
#   '还',
#   '二'],
#  ['告诉', '我', '最近', '的', '从', '西单', '到', '的', '开车', '路线'],
#  ['等会儿', '帮', '我', '把', '电脑', '打开'],
#  ['零点', '已经', '播出', '的', '赛事', '-', '回看', '一下'],
#  ['帮', '我', '找', '2001', '年', '的', '康熙', '王朝'],
#  ['来', '一个', '频率', '是', '九二', '点', '四', '的', '海上', '戏剧', '吧'],
#  ['我',
#   '现在',
#   '要',
#   '从',
#   '郑州',
#   '开车',
#   '到',
#   '杭州',
#   '看',
#   '话剧',
#   '，',
#   '帮',
#   '我',
#   '看看',
#   '路线',
#   '咋',
#   '走',
#   '的'],
#  ['一年', '七月', '二', '九日', '两人', '在', '天津', '正式'],
#  ['放', '一个', '乔丹', '的', '纪录片'],
#  ['我', '想', '看', '以前', '唱歌', '的', '视频'],
#  ['5',
#   '月',
#   '26',
#   '日',
#   'CCTV1',
#   '在',
#   '2',
#   '点',
#   '31',
#   '精彩',
#   '一刻',
#   '-',
#   '2020',
#   '-',
#   '186',
#   '新',
#   '航拍',
#   '中国',
#   '湖南',
#   '洞庭湖',
#   '视频',
#   '回放',
#   '一下'],
#  ['瞧瞧', '武侠剧', '绝代', '双骄', '。'],
#  ['现在',
#   '是',
#   '上午',
#   '十点',
#   '，',
#   '黑龙江',
#   '少儿',
#   '有',
#   '什么',
#   '适合',
#   '3',
#   '到',
#   '6',
#   '岁',
#   '的',
#   '节目',
#   '看'],
#  ['麻烦', '给', '我', '播放', '德云社', '的', '相声'],
#  ['济南', '故事', '广播', '的', '小说', '抢先', '听', '找', '来', '听听', '在', '文艺', '台'],
#  ['制定', '个', '明天', '下午', '5', '点去', '图书馆', '的', '闹钟', '。'],
#  ['具体', '什么', '时候', '我', '也', '不', '知道'],
#  ['帮', '我', '找出', 'CCTV1', '在', '5', '月', '26', '的', '新闻联播', '视频'],
#  ['你', '可以', '告诉', '我', '一下', '周六', '是', '农历', '几时'],
#  ['将', '浴霸', '调到', '强', '暖', '模式', '行嘛'],
#  ['想要', '知道', '开往', '哈尔滨', '的', '动车', '哪天', '有', '呀'],
#  ['我',
#   '爱',
#   '健康',
#   '这个',
#   '节目',
#   '还是',
#   '在',
#   '七点',
#   '多',
#   '开播',
#   '吗',
#   '帮',
#   '我',
#   '看',
#   '下'],
#  ['查找', '电影', '最好', '的', '我们', '预告'],
#  ['去年', '最火', '的', '抖音', '歌曲', '随机', '来', '一个', '呢'],
#  ['大前天', '是', '农历', '的', '哪天'],
#  ['随便', '放', '一首', '那', '女孩', '对', '我', '说', '里', '的', '歌'],
#  ['马上', '将', '1', '月', '1', '号', '去', '马鞍山', '的', '备忘录', '删除'],
#  ['18', '点有', '天津', '始发', '到', '济南', '的', '动车', '吗'],
#  ['空调', '风', '小点', '5', '吧'],
#  ['疼痛', '可以', '吃', '吗'],
#  ['快给我', '放', '下午', '3', '点', '开始', '的', '女子双打'],
#  ['月', '的', '教程', '视频', '给', '我', '找', '一个'],
#  ['电磁炉', '开启', '大', '火力'],
#  ['你', '能', '把', '喜剧', '羞羞', '的', '铁拳', '给', '我', '放', '出来', '吗'],
#  ['我', '想', '看', '一个', '去年', '大陆', '的', '偶像剧', '，', '不', '狗血', '的', '那种'],
#  ['2006', '年', '日本', '上线', '的', '电影', '随机', '播放', '一个', '给', '我', '看'],
#  ['我要', '听', '与', '荒野', '里面', '的', '呢'],
#  ['查查', '下个月', '6', '号', '18', '点去', '深圳', '的', '航班'],
#  ['我要', '看', '沈腾', '的', '喜剧', '作品'],
#  ['有声', '的', '紫襟', '说', '的', '灵异', '的', '小说', '帮', '我播', '一下'],
#  ['我', '现在', '要', '听', '约翰', '.', '的', '小说', '的', '这部', '小说'],
#  ['看', '一下', '小丽', '的', '生日', '五月', '初三', '是', '几号', '呀'],
#  ['有', '正放', '摇滚', '歌', '的', '音乐', '电台', '吧', '找', '来', '听'],
#  ['12', '点', '了', '看', '会儿', '午间', '新闻', '吧'],
#  ['想', '听', '一首', '英语', '摇滚'],
#  ['播放', '一下', '明天', '的', '天气预报'],
#  ['我', '想', '看', '康乐', '嘉年华', '，', '中午', '11', '点有', '播放', '吗'],
#  ['日语', '的', '歌曲', '随机', '来', '一首'],
#  ['帮', '我', '查看', '一下', 'CCTV1', '的', '朝闻', '天下', '往期', '视频'],
#  ['放', '一下', '4', '月', '16', '日', '的', '绝地', '求生', '游戏', '讲解', '视频'],
#  ['你', '以后', '不用', '每天', '6', '点', '喊', '我', '起床', '了'],
#  ['作者', '是', '的', '广播剧', '播放', '一个', '给', '我'],
#  ['香港', '的', '电视剧', '流金岁月', '第十集', '花絮', '播放', '出来'],
#  ['给', '我', '听'],
#  ['我', '想', '现在', '就', '看', '一下', '长', '歌行', '的', '第一集'],
#  ['播放', '一下', '爆笑', '相声', '我', '是'],
#  ['我', '需要', '一个', '的', '古装剧', '看', '一会', '呢'],
#  ['上', '我', '希望', '能够', '跟', '的', '人', '就', '好', '这样', '对', '小孩', '成长'],
#  ['放', '一个', '岳云鹏', '的', '相声', '生活', '来', '给', '我', '听'],
#  ['帮', '我', '调到', '新闻', '综合', '我', '想', '看看', '三农', '时空'],
#  ['我要', '听', '花木兰', '这个', '小', '故事'],
#  ['播放', '一下', '那个'],
#  ['特别', '是', '晚上', '睡觉', '的', '时候'],
#  ['那', '怎么', '才能', '从', '到', '博士', '只用'],
#  ['洗衣机', '开始', '脱水', '了', '吗', '，', '有点'],
#  ['请调', '到', '今天', '的', '湖南', '经济', '广播', '，', '我', '想', '听', '新闻'],
#  ['快给我', '查查', '去', '聊城', '的', '客车', '是', '几点', '的', '呀'],
#  ['现在', '收听', '主持', '的', '小黄瓜', '电台'],
#  ['也', '祝', '你', '全家', '圣诞节', '快乐'],
#  ['在', '，', '你', '是', '吗', '，', '这', '首歌', '给', '我', '单曲', '播放'],
#  ['给', '我续播', '玄幻', '小说', '魔兽', '异界', '的', '第三章'],
#  ['液晶电脑', '正', '液晶电脑', '好', '很多', '吗'],
#  ['现在', '马上', '搜', '一下', '2', '月', '1', '日', '是', '阴历', '多少', '呀'],
#  ['播放', '《', '是否', '我', '真的', '一无所有', '》', '，', '王杰', '老师', '的'],
#  ['播放', '明天', '重庆', '天气状况'],
#  ['放', '一首', '表达', '爱情', '的', '英文歌曲', '呢'],
#  ['给', '我', '打开', '爆笑', '吃', '你', '如何', '5', '人', '的', '游戏', '教学', '视频'],
#  ['相信', '有', '一天', '我会', '让', '你', '死', '得', '很', '难看'],
#  ['请问', '一下', '情人节', '是', '周几'],
#  ['循环', '播放', '2017', '年', '春晚', '小品', '家', '的', '味道', '听听看'],
#  ['播', '一下', '白居易', '的'],
#  ['回看',
#   'CCTV3',
#   '综艺',
#   '频道',
#   '的',
#   '向',
#   '幸福',
#   '出发',
#   '-',
#   '2021',
#   '-',
#   '18',
#   '五一',
#   '二',
#   '护士节'],
#  ['找', '一下', '莫文蔚', '2019', '演唱会', '唱歌', '的', '视频'],
#  ['查询', '北川', '明天', '是', '晴天', '吗'],
#  ['请', '帮', '我', '找到', 'FM89', '点', '9', '的', '东方', '都市', '广播'],
#  ['提醒', '我', '今天下午', '3', '点', '去取', '快递'],
#  ['查找', '并', '把', '坐', '公交', '去', '银行', '的', '路线', '给', '我', '来', '一条'],
#  ['播放', '一下', '国创', '动漫'],
#  ['杨金', '的', '快乐', '找到', '我', '想', '听听'],
#  ['帮', '我', '把', '冰箱', '的', '电源', '关掉', '。'],
#  ['告诉', '他', '沈阳', '开往', '哈尔滨', '的', '动车', '哪天', '有', '呀'],
#  ['湖南', '电影', '找下', '今天', '最', '感人', '的', '电影', '。'],
#  ['我', '想', '知道', '前天', '是', '礼拜', '几', '啊'],
#  ['帮', '我', '让', '洗衣机', '脱水', '吧'],
#  ['5', '月', '1', '号', '去', '重庆', '的', '备忘录', '你', '帮', '我建', '好了吗', '？'],
#  ['来', '钢琴演奏', '的', '英文歌曲'],
#  ['日本', '剧场版', '播放', '一下', '吧'],
#  ['我', '想', '看', '2020', '年谍', '战', '电视剧', '的', '幕后', '故事'],
#  ['请放', '一个', '小', '乌鸦', '喝水', '的', '故事'],
#  ['周六', '天气', '怎么样', '我要', '去', '逛街', '的'],
#  ['立刻', '收听', '频率', '是', '九', '三点', '八', '重庆', '都市', '电台'],
#  ['告诉', '我', '12', '月', '24', '和', '12', '月', '25', '都', '是', '阴历', '多少'],
#  ['我', '想', '看', '一个', '比较', '有', '笑', '点', '的', '古装', '电影'],
#  ['我要', '听', '沈以诚', '的', '民谣'],
#  ['2019', '年', '的', '电视剧', '插曲', '最火', '的', '播放', '呢'],
#  ['我', '要查', '后天', '去', '南京', '的', '汽车票'],
#  ['找', '几个', '美国', '动漫', '视频', '小', '来', '看看'],
#  ['门前', '妻子', '邓文迪', '与', '章子怡', '关系'],
#  ['麻烦', '调到', 'FM91', '点', '4', '成都', '电台', '交通广播'],
#  ['查看', '昨天', '9', '点', '广西', '卫视', '播放', '的', '是', '什么', '节目'],
#  ['现在', '请', '给', '放', '无所畏惧', '的', '王子', '这个', '故事', '的', '俄语', '版'],
#  ['定上', '一个', '9', '点', '55', '的', '闹钟'],
#  ['快给我', '播', '一首', '李清照', '的', '诗词'],
#  ['这时候', '关掉', '摄像头', '吧'],
#  ['要', '喊', '的', '我', '在', '啊'],
#  ['是不是', '能', '收听', '一下', '频率', '是', '一零', '四点', '零', '的', '人民', '广播电台', '啊'],
#  ['畲诗曼', '与', '绯闻', '男友', '好'],
#  ['接着', '播放', '恐怖', '小说', '的', '第三章'],
#  ['2018', '荒野', '里面', '的', '歌唱', '一首', '给', '我', '听', '呢'],
#  ['国庆节', '是', '农历', '8', '月', '16', '吗'],
#  ['赵丽颖演', '的', '电视剧', '有', '幕后', '花絮', '么'],
#  ['传奇', '之', '之战', '正在', '直播', '中', '观看', '一下'],
#  ['南京', '的'],
#  ['老鸟', '的', '万物', '可', '之', '这个', '游戏', '视频', '是', '什么', '时候', '讲', '的'],
#  ['最近', '大理', '气温', '很', '高', '吗'],
#  ['如果', '白天', '擦', '疤痕', '晚上', '擦', '那', '需要', '多久', '疤痕', '才能', '完全', '消失'],
#  ['查找', '动漫'],
#  ['那',
#   '就',
#   '帮',
#   '我定',
#   '一个',
#   '周日',
#   '下午',
#   '3',
#   '点',
#   '左右',
#   '去',
#   '地道战',
#   '参观',
#   '的',
#   '闹钟',
#   '。'],
#  ['有', '下午', '5', '点', '的', '英雄', '联盟', '比赛', '视频', '么', '，', '放', '来', '看看'],
#  ['开始', '播放', '一首', '关于', '爱情', '的', '古典音乐', '吧'],
#  ['星期五', '下午', '会', '下雨', '吗', '吗', '？'],
#  ['热水器', '的', '温度', '太高', '了', '，', '帮', '我', '一点'],
#  ['帮', '我', '打开', '南昌', '精品', '房产', '吧', '，', '想', '了解', '今天', '的'],
#  ['给', '我', '拨', '一下', '104', '点', '2', '蚌埠', '经济', '广播电台'],
#  ['好', '啦', '关掉', '客厅', '的', '灯', '吧'],
#  ['我', '想', '知道', '农历', '3', '月', '4', '日', '是', '周几'],
#  ['今天天气', '有点', '着', '加', '衣服', '了', '我会', '的'],
#  ['回放', '前天', '凌晨', '两点', '播放', '的', '我', '最', '爱', '的', '电视剧', '吧'],
#  ['西藏', '紫外线', '指数', '多少', '啊', '今天'],
#  ['的', '娱乐圈', '没有', '永远', '的', '正面', '只有', '永远', '的', '媒体'],
#  ['给', '我', '播放', '惊悚', '类', '的', '有声', '漫画'],
#  ['查询', '六月', '天津', '降雨量', '为', '多少'],
#  ['是不是', '能', '播放', '一下', '2020', '年', '播出', '的', '郭德纲', '的', '呢'],
#  ['给', '我播', '一下', '100', '点', '8', '的', '电台节目'],
#  ['饰演', '老大', '饰演', '他', '的', '弟弟'],
#  ['我', '正在', '收听', '的', '是', '的', '交通', '文艺', '广播'],
#  ['主演', '的', '电影', '岁月', '神偷', '。'],
#  ['能', '不能', '播放', '喜剧类', '的', '小品', '让', '我', '开心', '一下'],
#  ['韩国', '电影', '的', '拍摄', '花絮', '帮', '我', '找', '一下'],
#  ['放', '一下', '2020', '年', '央视春晚', '小品', '听'],
#  ['我', '想', '看', '美国', '范', '迪塞尔', '拍', '的', '剧', '呢'],
#  ['遂溪', '的', '能', '不能', '上'],
#  [' ', '汪峰', '版', '吧'],
#  ['2', '月', '1', '号', '是', '农历', '的', '几月', '几号'],
#  ['有道', '播放', '一下'],
#  ['传奇', '今天', '晚上', '19.00', '开播', '吗', '帮', '我', '看', '下'],
#  ['天官赐福', '的', '有声', '漫画', '帮', '我播', '一下'],
#  ['定',
#   '一个',
#   '6',
#   '月',
#   '13',
#   '号',
#   '下午',
#   '3',
#   '点',
#   '和',
#   '同学',
#   '打',
#   '的',
#   '行程',
#   '。'],
#  ['你', '可以', '给', '我', '来', '一个', '2019', '年', '的', '电影', '吗'],
#  ['给', '我播', '一个', '英文版', '的', '吧'],
#  ['播放', '管虎', '导演', '的', '内地', '的', '电影', '金刚'],
#  ['以后', '走', '不', '走', '这', '条路', '我', '说', '了'],
#  ['放', '一个', '宋', '小宝', '的', '搞笑', '小品', '来看', '一下'],
#  ['我', '现在', '心情', '不好', '你', '不要', '我'],
#  ['帮忙', '查下', '日历', '大前天', '是', '礼拜', '几', '啊'],
#  ['凌晨', '两点', '的', '电影吧', '结束', '了', '吗', '帮', '我', '看', '下'],
#  ['帮', '我', '我', '的', '微博'],
#  ['放', '一个', '春晚', '小品', '将', '爱情', '进行', '到底', '来', '听'],
#  ['宫斗剧', '甄', '嬛', '传', '可以', '继续', '播放', '一下', '么'],
#  ['空中', '-', '2021', '-', ' ', '京剧', '《', '》', '往期', '视频', '回看', '一下'],
#  ['外星人', '整个', '一共', '进', '了', '几个'],
#  ['看', '一个', '美国', '今年', '上映', '的', '剧情片', '吧'],
#  ['4', '月', '19', '日', '的', '农历', '是', '多少'],
#  ['我', '想', '听', '一个', '韩寒', '写', '的', '小说'],
#  ['播', '一下', '俄语', '版', '的', '小说', '追', '风筝', '的', '听'],
#  ['能', '不能', '随机', '来', '一首', '民谣', '呢'],
#  ['搜索', '一下', '少儿', '频道', '昨天下午', '播出', '的', '节目'],
#  ['我',
#   '想',
#   '听',
#   '一会',
#   '频率',
#   '是',
#   '一零',
#   '七点',
#   '八',
#   '的',
#   '湖北',
#   '人民',
#   '广播电台',
#   '交通',
#   '音乐台',
#   '呢'],
#  ['其中', '某', '一线', '某', '青年', '一线', '女', '在', '之'],
#  ['吧', '消息'],
#  ['小说', '我', '放', '一下'],
#  ['帮', '我', '设置', '一个', '中午', '1', '点', '给', '孩子', '的', '闹钟'],
#  ['今年', '的', '几月', '几号', '是'],
#  ['频率', '是', '一零', '三点', '九', '的', '人民', '广播电台', '继续', '听'],
#  ['赶紧', '说', '一下', '后天', '有', '开往', '潍坊', '的', '大巴', '吗'],
#  ['问', '到', '跟', '绯闻', '男友'],
#  ['我', '想', '知道', '柳州', '星期二', '下午', '两点', '半', '的', '风向', '。'],
#  ['你', '叫', '什么', '名字', '我', '问', '的', '是', '你', '叫', '什么', '名字'],
#  ['音乐', '节奏', '唱歌', '的', '要', '都', '搭配', '得', '进去', '还有', '文字', '上', '和', '的'],
#  ['你', '给', '我', '来', '几首', '2021', '年', '最', '火爆', '的', '抖音', '神曲', '吧'],
#  ['被', '蛇'],
#  ['请', '收听', '天津', '联盟', '广播', '岁月'],
#  ['继续', '放', '的', '阳光'],
#  ['我', '想', '知道', '去', '长沙', '最', '便宜', '的', '飞机', '航班', '是', '哪趟'],
#  ['平潭', '湿度', '是', '多少'],
#  ['同时', '他', '还', '成为', '中国', '电影', '的'],
#  ['我', '想', '看', '张大', '仙', '每日', '仙', '的', '最新', '一期', '的', '游戏', '视频'],
#  ['透露', '正', '新片'],
#  ['夏天', '成', '剧组', '高温', '雷雨'],
#  ['播放', '欧美', '动漫', '变形金刚'],
#  ['快给我', '放', '一个', '童话故事'],
#  ['古代', '的', '药', '就是', '现在', '的'],
#  ['将', '灯光', '调', '为', '温馨', '模式', '好', '么'],
#  ['的', '大厦', '哪里'],
#  ['给', '我', '来', '一首', '内', '的', '歌曲', '吧'],
#  ['赶紧', '帮', '我', '设定', '周五', '上午', '10', '点', '30', '分', '参加', '的', '提醒', '。'],
#  ['看过',
#   '国外',
#   '许多',
#   '末日',
#   '科幻电影',
#   '后',
#   '流浪',
#   '地球',
#   '并',
#   '没',
#   '给',
#   '我',
#   '太',
#   '多',
#   '惊喜'],
#  ['收听', '91', '点', '4', '的', '成都', '交通广播'],
#  ['放', '一下', '天天向上'],
#  ['50', '分钟', '之后', '记得', '提醒', '我', '吃药'],
#  ['找下', '到', '小学', '的', '路'],
#  ['我', '想', '看', '北京', '卫视', '的', '北京', '早', '帮', '我', '搜索', '一下', '往期', '视频'],
#  ['播放', '一个', '主演', '电视剧', '的', '介绍', '视频'],
#  ['你', '晚上', '睡不着', '的', '时候', '想', '男人', '吗'],
#  ['我', '想', '看', '一会', '台湾', '偶像剧', '呢', '最好', '是', '现代', '的', '不要', '古代', '的'],
#  ['重播', '7', '点', '37', '剧场', '你', '迟到', '的'],
#  ['昨日', '传出', '消息', '西安', '了'],
#  ['放', '一下', '春江花月夜', '这首', '古诗', '来', '听', '一下'],
#  ['帮', '我', '报', '一下', '是不是', '德州', '到', '济南', '的', '大巴', '到', '站', '了'],
#  ['让', '我', '看看', '你', '长', '的', '什么样'],
#  ['11', '号', '下午', '1', '点钟', '陪', '姐姐', '去', '的', '行程', '设定', '一下', '。'],
#  ['查询', '烟台', '温差', '最近', '情况'],
#  ['大理', '紫外线', '指数', '怎么样'],
#  ['听',
#   '一下',
#   '江南',
#   '主播',
#   '的',
#   '第一',
#   '房产',
#   '，',
#   '这是',
#   '石家庄',
#   '新闻',
#   '广播电台',
#   '播出',
#   '的'],
#  ['到', '中山', '怎么', '去'],
#  ['我', '好', '想', '听', '电影', '专辑', '，', '把', '那首', '爵士乐', '单曲', '循环'],
#  ['演', '的', '找', '一下'],
#  ['帮', '我', '打开', '下', '辽宁', '经济', '，', '我', '想', '了解', '一下', '今天', '的', '新闻'],
#  ['广州', '法制', '的', '直播', '今天', '六点', '开播', '吗', '帮', '我', '看', '下'],
#  ['我要', '听', '九十年代', '的'],
#  ['想', '听', '李清照', '的'],
#  ['快点儿', '打开', '厨房', '的'],
#  ['找到', '并且', '播放', '2006', '年', '的'],
#  ['已经', '出来', '了', '可以', '查询', '了'],
#  ['不', '知道', '今晚', '的', '中央', '什么', '节目', '看', '，', '帮', '我', '看', '下'],
#  ['立刻', '告诉', '我', '长沙', '去往', '杭州', '的', '动车', '哪天', '有票', '啊'],
#  ['明天', '4', ':', '00', '记得', '提醒', '我', '拿'],
#  ['点', '六五', '几'],
#  ['小点', '客厅', '空调', '风速'],
#  ['陈豪', '邓萃雯', '畲诗曼', '陈', '等', '到场', '出席'],
#  ['群星', '星光', '演唱会', '有', '谁'],
#  ['下周一', '视频会议', '的', '闹钟', '帮', '我', '开开']]

# %%
from gensim.models import Word2Vec

def transform2vector(corpus, vector_size):
    model = Word2Vec(corpus, vector_size=vector_size, window=5, min_count=1, workers=4)

    # 训练模型
    model.train(corpus, total_examples=len(corpus), epochs=10)
    # 保存模型
    model.save("word2vec_model.model")
    
    array = []
    for i, sentence in enumerate(corpus):
        vector = [model.wv[word] for word in sentence]
        vector_mean = np.mean(vector, axis=0)
        array.append(vector_mean)
    train_vector = pd.DataFrame(array)
    
    return train_vector

# %%
train_vector = transform2vector(processed_corpus, vector_size=200)
train_vector['label'] = train_data[1]

print("*" * 10 + "KNN" + "*" * 10)

cv_pred = cross_val_predict(
    KNeighborsClassifier(),
    train_vector.iloc[:, :-1], train_vector['label']
)
pprint.pprint(classification_report(train_data[1], cv_pred))

print("*" * 10 + "SVC" + "*" * 10)

cv_pred = cross_val_predict(
    LinearSVC(),
    train_vector.iloc[:, :-1], train_vector['label']
)
pprint.pprint(classification_report(train_data[1], cv_pred))

print("*" * 10 + "LogisticRegression" + "*" * 10)

cv_pred = cross_val_predict(
    LogisticRegression(),
    train_vector.iloc[:, :-1], train_vector['label']
)
pprint.pprint(classification_report(train_data[1], cv_pred))
# Out:
# **********KNN**********
# ('                       precision    recall  f1-score   support\n'
#  '\n'
#  '         Alarm-Update       0.95      0.95      0.95      1264\n'
#  '           Audio-Play       0.40      0.55      0.46       226\n'
#  '       Calendar-Query       0.97      0.96      0.96      1214\n'
#  '        FilmTele-Play       0.69      0.75      0.72      1355\n'
#  'HomeAppliance-Control       0.94      0.94      0.94      1215\n'
#  '           Music-Play       0.80      0.78      0.79      1304\n'
#  '                Other       0.22      0.19      0.20       214\n'
#  '         Radio-Listen       0.93      0.84      0.88      1285\n'
#  '       TVProgram-Play       0.55      0.56      0.55       240\n'
#  '         Travel-Query       0.92      0.95      0.93      1220\n'
#  '           Video-Play       0.83      0.79      0.81      1334\n'
#  '        Weather-Query       0.91      0.90      0.91      1229\n'
#  '\n'
#  '             accuracy                           0.85     12100\n'
#  '            macro avg       0.76      0.76      0.76     12100\n'
#  '         weighted avg       0.85      0.85      0.85     12100\n')
# **********SVC**********
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 14
#      10 pprint.pprint(classification_report(train_data[1], cv_pred))
#      12 print("*" * 10 + "SVC" + "*" * 10)
# ---> 14 cv_pred = cross_val_predict(
#      15     LinearSVC(),
#      16     train_vector.iloc[:, :-1], train_vector['label']
#      17 )
#      18 pprint.pprint(classification_report(train_data[1], cv_pred))
#      20 print("*" * 10 + "LogisticRegression" + "*" * 10)
#
# File d:\envs\a2\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File d:\envs\a2\Lib\site-packages\sklearn\model_selection\_validation.py:1293, in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, params, pre_dispatch, method)
#    1290 # We clone the estimator to make sure that all the folds are
#    1291 # independent, and that it is pickle-able.
#    1292 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# -> 1293 predictions = parallel(
#    1294     delayed(_fit_and_predict)(
#    1295         clone(estimator),
#    1296         X,
#    1297         y,
#    1298         train,
#    1299         test,
#    1300         routed_params.estimator.fit,
#    1301         method,
#    1302     )
#    1303     for train, test in splits
#    1304 )
#    1306 inv_test_indices = np.empty(len(test_indices), dtype=int)
#    1307 inv_test_indices[test_indices] = np.arange(len(test_indices))
#
# File d:\envs\a2\Lib\site-packages\sklearn\utils\parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File d:\envs\a2\Lib\site-packages\joblib\parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File d:\envs\a2\Lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File d:\envs\a2\Lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File d:\envs\a2\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File d:\envs\a2\Lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File d:\envs\a2\Lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File d:\envs\a2\Lib\site-packages\sklearn\utils\parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File d:\envs\a2\Lib\site-packages\sklearn\model_selection\_validation.py:1378, in _fit_and_predict(estimator, X, y, train, test, fit_params, method)
#    1376     estimator.fit(X_train, **fit_params)
#    1377 else:
# -> 1378     estimator.fit(X_train, y_train, **fit_params)
#    1379 func = getattr(estimator, method)
#    1380 predictions = func(X_test)
#
# File d:\envs\a2\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File d:\envs\a2\Lib\site-packages\sklearn\svm\_classes.py:325, in LinearSVC.fit(self, X, y, sample_weight)
#     319 self.classes_ = np.unique(y)
#     321 _dual = _validate_dual_parameter(
#     322     self.dual, self.loss, self.penalty, self.multi_class, X
#     323 )
# --> 325 self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#     326     X,
#     327     y,
#     328     self.C,
#     329     self.fit_intercept,
#     330     self.intercept_scaling,
#     331     self.class_weight,
#     332     self.penalty,
#     333     _dual,
#     334     self.verbose,
#     335     self.max_iter,
#     336     self.tol,
#     337     self.random_state,
#     338     self.multi_class,
#     339     self.loss,
#     340     sample_weight=sample_weight,
#     341 )
#     342 # Backward compatibility: _fit_liblinear is used both by LinearSVC/R
#     343 # and LogisticRegression but LogisticRegression sets a structured
#     344 # `n_iter_` attribute with information about the underlying OvR fits
#     345 # while LinearSVC/R only reports the maximum value.
#     346 self.n_iter_ = n_iter_.max().item()
#
# File d:\envs\a2\Lib\site-packages\sklearn\svm\_base.py:1217, in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#    1214 sample_weight = _check_sample_weight(sample_weight, X, dtype=np.float64)
#    1216 solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
# -> 1217 raw_coef_, n_iter_ = liblinear.train_wrap(
#    1218     X,
#    1219     y_ind,
#    1220     sp.issparse(X),
#    1221     solver_type,
#    1222     tol,
#    1223     bias,
#    1224     C,
#    1225     class_weight_,
#    1226     max_iter,
#    1227     rnd.randint(np.iinfo("i").max),
#    1228     epsilon,
#    1229     sample_weight,
#    1230 )
#    1231 # Regarding rnd.randint(..) in the above signature:
#    1232 # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#    1233 # on 32-bit platforms, we can't get to the UINT_MAX limit that
#    1234 # srand supports
#    1235 n_iter_max = max(n_iter_)
#
# KeyboardInterrupt:
